# %% [markdown]
# # 1 Data Preprocessing
# Each predicted keypoint is specified by an (x,y) real-valued pair in the space of pixel indices. There are 15 keypoints, which represent the following elements of the face:
#
# left_eye_center, right_eye_center, left_eye_inner_corner, left_eye_outer_corner, right_eye_inner_corner, right_eye_outer_corner, left_eyebrow_inner_end, left_eyebrow_outer_end, right_eyebrow_inner_end, right_eyebrow_outer_end, nose_tip, mouth_left_corner, mouth_right_corner, mouth_center_top_lip, mouth_center_bottom_lip
#
# Left and right here refers to the point of view of the subject.
#
# In some examples, some of the target keypoint positions are misssing (encoded as missing entries in the csv, i.e., with nothing between two commas).
#
# The input image is given in the last field of the data files, and consists of a list of pixels (ordered by row), as integers in (0,255). The images are 96x96 pixels.
#
#
#
# ## Preprocessing Data Files:
# training.csv: list of training 7049 images. Each row contains the (x,y) coordinates for 15 keypoints, and image data as row-ordered list of pixels.
# test.csv: list of 1783 test images. Each row contains ImageId and image data as row-ordered list of pixels
# submissionFileFormat.csv: list of 27124 keypoints to predict. Each row contains a RowId, ImageId, FeatureName, Location. FeatureName are "left_eye_center_x," "right_eyebrow_outer_end_y," etc. Location is what you need to predict.

# %% [markdown]
# ## 1.1 Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output
from time import sleep
import os

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Activation, Dropout, Dense, Flatten, MaxPooling2D, BatchNormalization
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, CSVLogger, ModelCheckpoint, EarlyStopping, LearningRateScheduler

# %% [markdown]
# ## 1.2 Import data files

# %%
Train_Dir = '/content/drive/My Drive/F19/CS 583 - Deep Learning/Assignments/final-project/data/training.csv'
Test_Dir = '/content/drive/My Drive/F19/CS 583 - Deep Learning/Assignments/final-project/data/test.csv'
lookid_dir = '/content/drive/My Drive/F19/CS 583 - Deep Learning/Assignments/final-project/data/IdLookupTable.csv'
train_data = pd.read_csv(Train_Dir)  
test_data = pd.read_csv(Test_Dir)
lookid_data = pd.read_csv(lookid_dir)
os.listdir('/content/drive/My Drive/F19/CS 583 - Deep Learning/Assignments/final-project/data')
# Out:
# ['.~lock.training.csv#',
#  'IdLookupTable.csv',
#  'SampleSubmission.csv',
#  'test.csv',
#  'training.csv']

# %% [markdown]
# ## 1.3 Training Data

# %% [markdown]
# ### 1.3.1 Look at the data
# take a look at the data

# %%
train_data.head().T
# Out:
#                                                                            0  ...                                                  4
# left_eye_center_x                                                    66.0336  ...                                            66.7253
# left_eye_center_y                                                    39.0023  ...                                            39.6213
# right_eye_center_x                                                    30.227  ...                                            32.2448
# right_eye_center_y                                                   36.4217  ...                                             38.042
# left_eye_inner_corner_x                                              59.5821  ...                                            58.5659
# left_eye_inner_corner_y                                              39.6474  ...                                            39.6213
# left_eye_outer_corner_x                                              73.1303  ...                                            72.5159
# left_eye_outer_corner_y                                                39.97  ...                                            39.8845
# right_eye_inner_corner_x                                             36.3566  ...                                            36.9824
# right_eye_inner_corner_y                                             37.3894  ...                                            39.0949
# right_eye_outer_corner_x                                             23.4529  ...                                            22.5061
# right_eye_outer_corner_y                                             37.3894  ...                                            38.3052
# left_eyebrow_inner_end_x                                             56.9533  ...                                            57.2496
# left_eyebrow_inner_end_y                                             29.0336  ...                                            30.6722
# left_eyebrow_outer_end_x                                             80.2271  ...                                            77.7629
# left_eyebrow_outer_end_y                                             32.2281  ...                                            31.7372
# right_eyebrow_inner_end_x                                            40.2276  ...                                            38.0354
# right_eyebrow_inner_end_y                                            29.0023  ...                                            30.9354
# right_eyebrow_outer_end_x                                            16.3564  ...                                            15.9259
# right_eyebrow_outer_end_y                                            29.6475  ...                                            30.6722
# nose_tip_x                                                           44.4206  ...                                            43.2995
# nose_tip_y                                                           57.0668  ...                                            64.8895
# mouth_left_corner_x                                                  61.1953  ...                                            60.6714
# mouth_left_corner_y                                                  79.9702  ...                                            77.5232
# mouth_right_corner_x                                                 28.6145  ...                                            31.1918
# mouth_right_corner_y                                                  77.389  ...                                            76.9973
# mouth_center_top_lip_x                                               43.3126  ...                                            44.9627
# mouth_center_top_lip_y                                               72.9355  ...                                            73.7074
# mouth_center_bottom_lip_x                                            43.1307  ...                                            44.2271
# mouth_center_bottom_lip_y                                            84.4858  ...                                            86.8712
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...  ...  147 148 160 196 215 214 216 217 219 220 206 18...
#
# [31 rows x 5 columns]

# %% [markdown]
# ### 1.3.2 Check for missing values

# %%
# on a per data point basis
train_data.T.isnull().any().value_counts()
# Out:
# True     4909
# False    2140
# dtype: int64

# %%
# on a per feature basis
train_data.isnull().any().value_counts()
# Out:
# True     28
# False     3
# dtype: int64

# %% [markdown]
# Out of 7049 images, 4909 has missing values.
# Out of 30 features, 28 have missing values.
#
# Options:
# 1. Eliminate rows with missing values
# 2. Fill missing values with average for that column
#
# It's not viable either to remove 28 features or get rid if 4909 data points, as it would mean losing a lot of information. I choose to fill the missing values by placing the average for that feature.
#
# Get the average of each feature:

# %%
# this takes the average of all features excluding the column that contains the image
# that column makes everything slow and its meaningless
feature_means = train_data.T[train_data.columns != "Image"].mean(axis=1, skipna=True)

# %%
feature_means_dict = feature_means.to_dict()

# %%
print(feature_means_dict)
# Out:
# {'left_eye_center_x': 66.35902124475341, 'left_eye_center_y': 37.65123419193394, 'right_eye_center_x': 30.306101514079742, 'right_eye_center_y': 37.976942571727, 'left_eye_inner_corner_x': 59.15933943740389, 'left_eye_inner_corner_y': 37.94475232796774, 'left_eye_outer_corner_x': 73.33047798314604, 'left_eye_outer_corner_y': 37.707008310793, 'right_eye_inner_corner_x': 36.65260694805726, 'right_eye_inner_corner_y': 37.98990191451049, 'right_eye_outer_corner_x': 22.384504479169365, 'right_eye_outer_corner_y': 38.03349517525045, 'left_eyebrow_inner_end_x': 56.06851307930932, 'left_eyebrow_inner_end_y': 29.332678249311783, 'left_eyebrow_outer_end_x': 79.4828258641995, 'left_eyebrow_outer_end_y': 29.734860732432328, 'right_eyebrow_inner_end_x': 39.322136922017485, 'right_eyebrow_inner_end_y': 29.502998474112978, 'right_eyebrow_outer_end_x': 15.871177472719145, 'right_eyebrow_outer_end_y': 30.428165911873492, 'nose_tip_x': 48.37418629032899, 'nose_tip_y': 62.71588359736168, 'mouth_left_corner_x': 63.2857351209867, 'mouth_left_corner_y': 75.97071433583544, 'mouth_right_corner_x': 32.90040370265751, 'mouth_right_corner_y': 76.17976785460502, 'mouth_center_top_lip_x': 47.97541157202031, 'mouth_center_top_lip_y': 72.91944259683731, 'mouth_center_bottom_lip_x': 48.569472172278324, 'mouth_center_bottom_lip_y': 78.97014624503694}

# %%
for label in feature_means_dict.keys():
    train_data[label].fillna(feature_means_dict[str(label)], inplace = True)

# %% [markdown]
# If everything ran smoothly, the means should remain the same (because adding the mean doesnt affect the mean) and there should be no columns with NaN

# %%
print(feature_means_dict)
# how many features have NaNs?
print("\nAny columns have NaN values?", train_data.isnull().any().value_counts())
print("Any rows with NaN values?", train_data.T.isnull().any().value_counts())
# Out:
# {'left_eye_center_x': 66.35902124475341, 'left_eye_center_y': 37.65123419193394, 'right_eye_center_x': 30.306101514079742, 'right_eye_center_y': 37.976942571727, 'left_eye_inner_corner_x': 59.15933943740389, 'left_eye_inner_corner_y': 37.94475232796774, 'left_eye_outer_corner_x': 73.33047798314604, 'left_eye_outer_corner_y': 37.707008310793, 'right_eye_inner_corner_x': 36.65260694805726, 'right_eye_inner_corner_y': 37.98990191451049, 'right_eye_outer_corner_x': 22.384504479169365, 'right_eye_outer_corner_y': 38.03349517525045, 'left_eyebrow_inner_end_x': 56.06851307930932, 'left_eyebrow_inner_end_y': 29.332678249311783, 'left_eyebrow_outer_end_x': 79.4828258641995, 'left_eyebrow_outer_end_y': 29.734860732432328, 'right_eyebrow_inner_end_x': 39.322136922017485, 'right_eyebrow_inner_end_y': 29.502998474112978, 'right_eyebrow_outer_end_x': 15.871177472719145, 'right_eyebrow_outer_end_y': 30.428165911873492, 'nose_tip_x': 48.37418629032899, 'nose_tip_y': 62.71588359736168, 'mouth_left_corner_x': 63.2857351209867, 'mouth_left_corner_y': 75.97071433583544, 'mouth_right_corner_x': 32.90040370265751, 'mouth_right_corner_y': 76.17976785460502, 'mouth_center_top_lip_x': 47.97541157202031, 'mouth_center_top_lip_y': 72.91944259683731, 'mouth_center_bottom_lip_x': 48.569472172278324, 'mouth_center_bottom_lip_y': 78.97014624503694}
#
# Any columns have NaN values? False    31
# dtype: int64
# Any rows with NaN values? False    7049
# dtype: int64

# %% [markdown]
# ### 1.3.3 Separate the training features from the training labels
# train_x = the image pixel values
#
# train_y = the locations of the keypoints

# %%
train_x = []

for image_idx in range(0,7049):
    img = train_data['Image'][image_idx].split(' ')
    img = ['0' if x == '' else x for x in img]
    train_x.append(img)

# %%
train_x = np.array(train_x, dtype = 'float32')
train_x = train_x.reshape(-1, 9216)
print(train_x.nbytes)
# Out:
# 259854336

# %%
plt.imshow(train_x[1000].reshape(96,96), cmap='gray')

# %% [markdown]
# Now that the train_x data is cleaned up and ready, lets take care of the labels.
#
# Currently, the labels are 15 features, represented by x and y coordinates, giving a total of 30 data fields.
#
# At first, I will attempt to train by concatenating all features of each image into a 30-dimensional vector of floats.

# %%
# remove the 'Image' column, as that has been placed in train_x already, and we dont need it to occupy memory any longer
train_data = train_data.drop('Image', axis=1)

# ensure that 'Image' Column was removed correctly
train_data.head().T
# Out:
#                                    0          1  ...          3          4
# left_eye_center_x          66.033564  64.332936  ...  65.225739  66.725301
# left_eye_center_y          39.002274  34.970077  ...  37.261774  39.621261
# right_eye_center_x         30.227008  29.949277  ...  32.023096  32.244810
# right_eye_center_y         36.421678  33.448715  ...  37.261774  38.042032
# left_eye_inner_corner_x    59.582075  58.856170  ...  60.003339  58.565890
# left_eye_inner_corner_y    39.647423  35.274349  ...  39.127179  39.621261
# left_eye_outer_corner_x    73.130346  70.722723  ...  72.314713  72.515926
# left_eye_outer_corner_y    39.969997  36.187166  ...  38.380967  39.884466
# right_eye_inner_corner_x   36.356571  36.034723  ...  37.618643  36.982380
# right_eye_inner_corner_y   37.389402  34.361532  ...  38.754115  39.094852
# right_eye_outer_corner_x   23.452872  24.472511  ...  25.307270  22.506110
# right_eye_outer_corner_y   37.389402  33.144443  ...  38.007903  38.305237
# left_eyebrow_inner_end_x   56.953263  53.987404  ...  56.433809  57.249571
# left_eyebrow_inner_end_y   29.033648  28.275949  ...  30.929864  30.672177
# left_eyebrow_outer_end_x   80.227128  78.634213  ...  77.910261  77.762945
# left_eyebrow_outer_end_y   32.228138  30.405923  ...  31.665725  31.737247
# right_eyebrow_inner_end_x  40.227609  42.728851  ...  41.671513  38.035436
# right_eyebrow_inner_end_y  29.002322  26.146043  ...  31.049990  30.935382
# right_eyebrow_outer_end_x  16.356379  16.865362  ...  20.458017  15.925870
# right_eyebrow_outer_end_y  29.647471  27.058860  ...  29.909343  30.672177
# nose_tip_x                 44.420571  48.206298  ...  51.885078  43.299534
# nose_tip_y                 57.066803  55.660936  ...  54.166539  64.889521
# mouth_left_corner_x        61.195308  56.421447  ...  65.598887  60.671411
# mouth_left_corner_y        79.970165  76.352000  ...  72.703722  77.523239
# mouth_right_corner_x       28.614496  35.122383  ...  37.245496  31.191755
# mouth_right_corner_y       77.388992  76.047660  ...  74.195478  76.997301
# mouth_center_top_lip_x     43.312602  46.684596  ...  50.303165  44.962748
# mouth_center_top_lip_y     72.935459  70.266553  ...  70.091687  73.707387
# mouth_center_bottom_lip_x  43.130707  45.467915  ...  51.561183  44.227141
# mouth_center_bottom_lip_y  84.485774  85.480170  ...  78.268383  86.871166
#
# [30 rows x 5 columns]

# %% [markdown]
# Now, place all 7049 30-dim vector of labels into a numpy array

# %%
train_y = [] 
for img_idx in range(0,7049):
  y = train_data.iloc[img_idx, :] 
  train_y.append(y)

train_y = np.array(train_y, dtype='float32')

# %% [markdown]
# Randomize the training data:

# %%
n = train_x.shape[0]

rand_indices = np.random.permutation(n)
train_indices = rand_indices[0:n]

# %%
train_x = train_x[train_indices]
train_y = train_y[train_indices]

# %% [markdown]
# ### 1.3.4 Place training data into a generator (omitted)

# %%
# from keras.preprocessing.image import ImageDataGenerator

# image_generator = ImageDataGenerator(
#                                     # horizontal_flip = True, 
#                                     # rotation_range = 10, 
#                                     # height_shift_range = 0.05, 
#                                     #  width_shift_range = 0.05
# )

# image_generator.fit(train_x)

# %% [markdown]
# ## 1.4 Test Data

# %% [markdown]
# ### 1.4.1 Prepare test data
#
# Just like I placed the "Image" column values into a numpy array of arrays in the training data, I'll do the same with the test data.

# %% [markdown]
# ### 1.4.2 Look at the test data
# How many data points are there in the test set?
# How is the test data formatted?

# %%
print(test_data.shape)
test_data.head()
# Out:
# (1783, 2)
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...

# %%
test_x = []

for img_idx in range(0, 1783):
  img = test_data['Image'][img_idx].split(' ')
  img = ['0' if x == '' else x for x in img]

  test_x.append(img)

# %%
# cast the data into a numpy array
test_x = np.array(test_x, dtype='float32')
test_x = test_x.reshape(-1, 9216)

# %%
# show an image to ensure reshaping and casting went well
plt.imshow(test_x[1782].reshape(96,96), cmap='gray')

# %% [markdown]
# ### 1.4.3 Understand the submission format

# %% [markdown]
# As part of the data, I was given a sample submission. Lets explore that file.

# %%
sample_submission_dir = '/content/drive/My Drive/F19/CS 583 - Deep Learning/Assignments/final-project/data/SampleSubmission.csv'
submission_data = pd.read_csv(sample_submission_dir)

# %%
submission_data.head()
# Out:
#    RowId  Location
# 0      1         0
# 1      2         0
# 2      3         0
# 3      4         0
# 4      5         0

# %% [markdown]
# Looks like there is just two columns, and 27124 rows. There is only a `rowId` to identify each row.
#
# Lets look at the fourth file we were given, and get some clues as to how this submission is wanted:

# %%
lookid_data.head()
# Out:
#    RowId  ImageId              FeatureName  Location
# 0      1        1        left_eye_center_x       NaN
# 1      2        1        left_eye_center_y       NaN
# 2      3        1       right_eye_center_x       NaN
# 3      4        1       right_eye_center_y       NaN
# 4      5        1  left_eye_inner_corner_x       NaN

# %% [markdown]
# Each row in the submission file has a rowID. We can use the `lookid_data` file to find which Image and which predicted feature belong to each rowID.

# %% [markdown]
# ## 1.5 Summary of Data Preprocessing
#
# During this first section, I got to understand how my data is provided to me, and what are the setbacks of the data that will make training harder.
#
# I found out that the data had lots of holes, with missing information on 4909 out of the 7049 images, almost 70% of my data points were incomplete!
#
# I opted for a solution that will take the average of the value for that feature among all datapoints.
#
# If I have more time, I would like to calculate the standard deviation of each feature, to see if using the mean of the feature to fill out the missing holes is actually a good estimate.
#
#
# For the test data, I formatted it the same way as the training data.

# %% [markdown]
# # 2 The Models
#
# Since I only have 7049 examples, I want to avoid overfitting. In this section **I will try different models**. Note that I will name these models differently, but **to run the "best" model only, you should skip the sections containing the "other" models.**

# %% [markdown]
# ## 2.1 Training a simple FC model
#
# I'll start with a very simple sequential model with a single fully connected hidden layer. I will use this initial as a baseline to compare to.

# %%
def build_simple_model():
  """function that defines model with 2 hidden layers, and compiles it. 
  returns compiled model"""
  model = Sequential()
  model.add(Dense(128, activation='relu', input_shape=(9216,)))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(30))

  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae', 'mse'])
  print(model.summary())
  return model

# %%
simple_model = build_simple_model()

simple_model_history = simple_model.fit(train_x, train_y, batch_size=32,
                           epochs=500, validation_split=0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                1950
# =================================================================
# Total params: 1,189,982
# Trainable params: 1,189,982
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 5639 samples, validate on 1410 samples
# Epoch 1
500
# 5639/5639 [==============================] - 1s 128us/step - loss: 1316.9184 - mean_absolute_error: 31.2301 - mean_squared_error: 1316.9184 - val_loss: 1311.8727 - val_mean_absolute_error: 31.1524 - val_mean_squared_error: 1311.8727
# Epoch 96/500
# 5639/5639 [==============================] - 1s 129us/step - loss: 1305.9065 - mean_absolute_error: 31.0585 - mean_squared_error: 1305.9065 - val_loss: 1300.8909 - val_mean_absolute_error: 30.9813 - val_mean_squared_error: 1300.8909
# Epoch 97/500
# 5639/5639 [==============================] - 1s 129us/step - loss: 1294.9596 - mean_absolute_error: 30.8874 - mean_squared_error: 1294.9596 - val_loss: 1289.9723 - val_mean_absolute_error: 30.8104 - val_mean_squared_error: 1289.9723
# Epoch 98/500
# 5639/5639 [==============================] - 1s 131us/step - loss: 1284.0722 - mean_absolute_error: 30.7165 - mean_squared_error: 1284.0722 - val_loss: 1279.1125 - val_mean_absolute_error: 30.6395 - val_mean_squared_error: 1279.1125
# Epoch 99/500
# 5639/5639 [==============================] - 1s 130us/step - loss: 1273.2438 - mean_absolute_error: 30.5456 - mean_squared_error: 1273.2438 - val_loss: 1268.3163 - val_mean_absolute_error: 30.4689 - val_mean_squared_error: 1268.3163
# Epoch 100/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 1262.4782 - mean_absolute_error: 30.3748 - mean_squared_error: 1262.4782 - val_loss: 1257.5774 - val_mean_absolute_error: 30.2982 - val_mean_squared_error: 1257.5774
# Epoch 101/500
# 5639/5639 [==============================] - 1s 131us/step - loss: 1251.7725 - mean_absolute_error: 30.2041 - mean_squared_error: 1251.7725 - val_loss: 1246.9011 - val_mean_absolute_error: 30.1275 - val_mean_squared_error: 1246.9011
# Epoch 102/500
# 5639/5639 [==============================] - 1s 129us/step - loss: 1241.1292 - mean_absolute_error: 30.0332 - mean_squared_error: 1241.1292 - val_loss: 1236.2842 - val_mean_absolute_error: 29.9569 - val_mean_squared_error: 1236.2842
# Epoch 103/500
# 5639/5639 [==============================] - 1s 130us/step - loss: 1230.5431 - mean_absolute_error: 29.8626 - mean_squared_error: 1230.5431 - val_loss: 1225.7294 - val_mean_absolute_error: 29.7864 - val_mean_squared_error: 1225.7294
# Epoch 104/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 1220.0176 - mean_absolute_error: 29.6919 - mean_squared_error: 1220.0176 - val_loss: 1215.2335 - val_mean_absolute_error: 29.6160 - val_mean_squared_error: 1215.2335
# Epoch 105/500
# 5639/5639 [==============================] - 1s 125us/step - loss: 1209.5522 - mean_absolute_error: 29.5213 - mean_squared_error: 1209.5522 - val_loss: 1204.7969 - val_mean_absolute_error: 29.4455 - val_mean_squared_error: 1204.7969
# Epoch 106/500
# 5639/5639 [==============================] - 1s 122us/step - loss: 1199.1493 - mean_absolute_error: 29.3508 - mean_squared_error: 1199.1493 - val_loss: 1194.4242 - val_mean_absolute_error: 29.2751 - val_mean_squared_error: 1194.4242
# Epoch 107/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 1188.8069 - mean_absolute_error: 29.1802 - mean_squared_error: 1188.8069 - val_loss: 1184.1089 - val_mean_absolute_error: 29.1048 - val_mean_squared_error: 1184.1089
# Epoch 108/500
# 5639/5639 [==============================] - 1s 127us/step - loss: 1178.5253 - mean_absolute_error: 29.0098 - mean_squared_error: 1178.5253 - val_loss: 1173.8565 - val_mean_absolute_error: 28.9346 - val_mean_squared_error: 1173.8565
# Epoch 109/500
# 5639/5639 [==============================] - 1s 129us/step - loss: 1168.3036 - mean_absolute_error: 28.8394 - mean_squared_error: 1168.3036 - val_loss: 1163.6626 - val_mean_absolute_error: 28.7643 - val_mean_squared_error: 1163.6626
# Epoch 110/500
# 5639/5639 [==============================] - 1s 131us/step - loss: 1158.1408 - mean_absolute_error: 28.6692 - mean_squared_error: 1158.1408 - val_loss: 1153.5312 - val_mean_absolute_error: 28.5942 - val_mean_squared_error: 1153.5312
# Epoch 111/500
# 5639/5639 [==============================] - 1s 124us/step - loss:
500
# 5639/5639 [==============================] - 1s 122us/step - loss: 7.4636 - mean_absolute_error: 1.3635 - mean_squared_error: 7.4636 - val_loss: 8.2254 - val_mean_absolute_error: 1.3831 - val_mean_squared_error: 8.2254
# Epoch 445/500
# 5639/5639 [==============================] - 1s 115us/step - loss: 7.4430 - mean_absolute_error: 1.3583 - mean_squared_error: 7.4430 - val_loss: 8.2071 - val_mean_absolute_error: 1.3784 - val_mean_squared_error: 8.2071
# Epoch 446/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 7.4268 - mean_absolute_error: 1.3546 - mean_squared_error: 7.4268 - val_loss: 8.1920 - val_mean_absolute_error: 1.3738 - val_mean_squared_error: 8.1920
# Epoch 447/500
# 5639/5639 [==============================] - 1s 118us/step - loss: 7.4131 - mean_absolute_error: 1.3501 - mean_squared_error: 7.4131 - val_loss: 8.1806 - val_mean_absolute_error: 1.3696 - val_mean_squared_error: 8.1806
# Epoch 448/500
# 5639/5639 [==============================] - 1s 128us/step - loss: 7.4028 - mean_absolute_error: 1.3459 - mean_squared_error: 7.4028 - val_loss: 8.1717 - val_mean_absolute_error: 1.3652 - val_mean_squared_error: 8.1717
# Epoch 449/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 7.3952 - mean_absolute_error: 1.3422 - mean_squared_error: 7.3952 - val_loss: 8.1653 - val_mean_absolute_error: 1.3621 - val_mean_squared_error: 8.1653
# Epoch 450/500
# 5639/5639 [==============================] - 1s 117us/step - loss: 7.3897 - mean_absolute_error: 1.3400 - mean_squared_error: 7.3897 - val_loss: 8.1610 - val_mean_absolute_error: 1.3589 - val_mean_squared_error: 8.1610
# Epoch 451/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 7.3861 - mean_absolute_error: 1.3363 - mean_squared_error: 7.3861 - val_loss: 8.1583 - val_mean_absolute_error: 1.3570 - val_mean_squared_error: 8.1583
# Epoch 452/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 7.3840 - mean_absolute_error: 1.3348 - mean_squared_error: 7.3840 - val_loss: 8.1566 - val_mean_absolute_error: 1.3555 - val_mean_squared_error: 8.1566
# Epoch 453/500
# 5639/5639 [==============================] - 1s 123us/step - loss: 7.3825 - mean_absolute_error: 1.3339 - mean_squared_error: 7.3825 - val_loss: 8.1554 - val_mean_absolute_error: 1.3544 - val_mean_squared_error: 8.1554
# Epoch 454/500
# 5639/5639 [==============================] - 1s 123us/step - loss: 7.3816 - mean_absolute_error: 1.3325 - mean_squared_error: 7.3816 - val_loss: 8.1547 - val_mean_absolute_error: 1.3537 - val_mean_squared_error: 8.1547
# Epoch 455/500
# 5639/5639 [==============================] - 1s 120us/step - loss: 7.3811 - mean_absolute_error: 1.3325 - mean_squared_error: 7.3811 - val_loss: 8.1542 - val_mean_absolute_error: 1.3536 - val_mean_squared_error: 8.1542
# Epoch 456/500
# 5639/5639 [==============================] - 1s 128us/step - loss: 7.3807 - mean_absolute_error: 1.3319 - mean_squared_error: 7.3807 - val_loss: 8.1538 - val_mean_absolute_error: 1.3535 - val_mean_squared_error: 8.1538
# Epoch 457/500
# 5639/5639 [==============================] - 1s 117us/step - loss: 7.3804 - mean_absolute_error: 1.3318 - mean_squared_error: 7.3804 - val_loss: 8.1536 - val_mean_absolute_error: 1.3534 - val_mean_squared_error: 8.1536
# Epoch 458/500
# 5639/5639 [==============================] - 1s 117us/step - loss: 7.3802 - mean_absolute_error: 1.3318 - mean_squared_error: 7.3802 - val_loss: 8.1534 - val_mean_absolute_error: 1.3536 - val_mean_squared_error: 8.1534
# Epoch 459/500
# 5639/5639 [==============================] - 1s 120us/step - loss: 7.3801 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3801 - val_loss: 8.1532 - val_mean_absolute_error: 1.3537 - val_mean_squared_error: 8.1532
# Epoch 460/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 7.3800 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3800 - val_loss: 8.1531 - val_mean_absolute_error: 1.3537 - val_mean_squared_error: 8.1531
# Epoch 461/500
# 5639/5639 [==============================] - 1s 123us/step - loss: 7.3799 - mean_absolute_error: 1.3325 - mean_squared_error: 7.3799 - val_loss: 8.1530 - val_mean_absolute_error: 1.3532 - val_mean_squared_error: 8.1530
# Epoch 462/500
# 5639/5639 [==============================] - 1s 118us/step - loss: 7.3798 - mean_absolute_error: 1.3326 - mean_squared_error: 7.3798 - val_loss: 8.1529 - val_mean_absolute_error: 1.3534 - val_mean_squared_error: 8.1529
# Epoch 463/500
# 5639/5639 [==============================] - 1s 122us/step - loss: 7.3798 - mean_absolute_error: 1.3326 - mean_squared_error: 7.3798 - val_loss: 8.1528 - val_mean_absolute_error: 1.3535 - val_mean_squared_error: 8.1528
# Epoch 464/500
# 5639/5639 [==============================] - 1s 136us/step - loss: 7.3798 - mean_absolute_error: 1.3324 - mean_squared_error: 7.3798 - val_loss: 8.1528 - val_mean_absolute_error: 1.3533 - val_mean_squared_error: 8.1528
# Epoch 465/500
# 5639/5639 [==============================] - 1s 127us/step - loss: 7.3798 - mean_absolute_error: 1.3319 - mean_squared_error: 7.3798 - val_loss: 8.1527 - val_mean_absolute_error: 1.3537 - val_mean_squared_error: 8.1527
# Epoch 466/500
# 5639/5639 [==============================] - 1s 118us/step - loss: 7.3798 - mean_absolute_error: 1.3319 - mean_squared_error: 7.3798 - val_loss: 8.1527 - val_mean_absolute_error: 1.3541 - val_mean_squared_error: 8.1527
# Epoch 467/500
# 5639/5639 [==============================] - 1s 128us/step - loss: 7.3797 - mean_absolute_error: 1.3323 - mean_squared_error: 7.3797 - val_loss: 8.1527 - val_mean_absolute_error: 1.3545 - val_mean_squared_error: 8.1527
# Epoch 468/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 7.3797 - mean_absolute_error: 1.3321 - mean_squared_error: 7.3797 - val_loss: 8.1527 - val_mean_absolute_error: 1.3549 - val_mean_squared_error: 8.1527
# Epoch 469/500
# 5639/5639 [==============================] - 1s 123us/step - loss: 7.3797 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3797 - val_loss: 8.1526 - val_mean_absolute_error: 1.3546 - val_mean_squared_error: 8.1526
# Epoch 470/500
# 5639/5639 [==============================] - 1s 122us/step - loss: 7.3797 - mean_absolute_error: 1.3325 - mean_squared_error: 7.3797 - val_loss: 8.1527 - val_mean_absolute_error: 1.3547 - val_mean_squared_error: 8.1527
# Epoch 471/500
# 5639/5639 [==============================] - 1s 134us/step - loss: 7.3797 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3797 - val_loss: 8.1527 - val_mean_absolute_error: 1.3550 - val_mean_squared_error: 8.1527
# Epoch 472/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 7.3798 - mean_absolute_error: 1.3324 - mean_squared_error: 7.3798 - val_loss: 8.1526 - val_mean_absolute_error: 1.3542 - val_mean_squared_error: 8.1526
# Epoch 473/500
# 5639/5639 [==============================] - 1s 120us/step - loss: 7.3797 - mean_absolute_error: 1.3323 - mean_squared_error: 7.3797 - val_loss: 8.1526 - val_mean_absolute_error: 1.3539 - val_mean_squared_error: 8.1526
# Epoch 474/500
# 5639/5639 [==============================] - 1s 126us/step - loss: 7.3797 - mean_absolute_error: 1.3321 - mean_squared_error: 7.3797 - val_loss: 8.1526 - val_mean_absolute_error: 1.3545 - val_mean_squared_error: 8.1526
# Epoch 475/500
# 5639/5639 [==============================] - 1s 127us/step - loss: 7.3798 - mean_absolute_error: 1.3327 - mean_squared_error: 7.3798 - val_loss: 8.1526 - val_mean_absolute_error: 1.3547 - val_mean_squared_error: 8.1526
# Epoch 476/500
# 5639/5639 [==============================] - 1s 120us/step - loss: 7.3798 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3798 - val_loss: 8.1527 - val_mean_absolute_error: 1.3546 - val_mean_squared_error: 8.1527
# Epoch 477/500
# 5639/5639 [==============================] - 1s 128us/step - loss: 7.3797 - mean_absolute_error: 1.3331 - mean_squared_error: 7.3797 - val_loss: 8.1526 - val_mean_absolute_error: 1.3537 - val_mean_squared_error: 8.1526
# Epoch 478/500
# 5639/5639 [==============================] - 1s 125us/step - loss: 7.3797 - mean_absolute_error: 1.3324 - mean_squared_error: 7.3797 - val_loss: 8.1525 - val_mean_absolute_error: 1.3536 - val_mean_squared_error: 8.1525
# Epoch 479/500
# 5639/5639 [==============================] - 1s 119us/step - loss: 7.3797 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3797 - val_loss: 8.1525 - val_mean_absolute_error: 1.3539 - val_mean_squared_error: 8.1525
# Epoch 480/500
# 5639/5639 [==============================] - 1s 121us/step - loss: 7
# Epoch 497/500
# 5639/5639 [==============================] - 1s 116us/step - loss: 7.3797 - mean_absolute_error: 1.3325 - mean_squared_error: 7.3797 - val_loss: 8.1528 - val_mean_absolute_error: 1.3536 - val_mean_squared_error: 8.1528
# Epoch 498/500
# 5639/5639 [==============================] - 1s 128us/step - loss: 7.3797 - mean_absolute_error: 1.3318 - mean_squared_error: 7.3797 - val_loss: 8.1528 - val_mean_absolute_error: 1.3536 - val_mean_squared_error: 8.1528
# Epoch 499/500
# 5639/5639 [==============================] - 1s 120us/step - loss: 7.3798 - mean_absolute_error: 1.3322 - mean_squared_error: 7.3798 - val_loss: 8.1526 - val_mean_absolute_error: 1.3533 - val_mean_squared_error: 8.1526
# Epoch 500/500
# 5639/5639 [==============================] - 1s 124us/step - loss: 7.3798 - mean_absolute_error: 1.3319 - mean_squared_error: 7.3798 - val_loss: 8.1527 - val_mean_absolute_error: 1.3535 - val_mean_squared_error: 8.1527

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

loss = simple_model_history.history['loss'][3:]
val_loss = simple_model_history.history['val_loss'][3:]

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = simple_model_history.history['mean_absolute_error'][3:]
val_mae = simple_model_history.history['val_mean_absolute_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %%
mse = simple_model_history.history['mean_squared_error'][3:]
val_mse = simple_model_history.history['val_mean_squared_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mse, 'bo', label='Training MSE')
plt.plot(epochs, val_mse, 'r', label='Validation MSE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# **Performance of Simple Model**
#
# The simple model does not overfit on the validation data even after training reaches a plateau.
# I will assume that plateau is just due to reaching the learning capacity of this simple model.
#
# I will confirm my suspicion by increasing the model capacity, and seeing if (with proper regularization) I can reach lower errors.

# %% [markdown]
# ### 2.1.2 Testing Simple model
#
# Now its time to prepare my first submission to the competition, and see how far down the leaderboard I get.
#
# ![hoping for the best](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQhp_4JhuO7JvxzZPOQQ5m_HrvVF-ltjCaktAxEQoimCEQe6kDO&s)

# %% [markdown]
# ### 2.1.3 Predict on the test data

# %%
pred = simple_model.predict(test_x)

# %% [markdown]
# ### 2.1.4 Create submission file

# %%
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)

# %%
rowid = list(lookid_data['RowId'])

# %%
feature = []

for f in lookid_list:
    feature.append(lookid_list.index(f))

# %%
preded = []

for x,y in zip(imageID, feature):
    preded.append(pre_list[x][y])

# %%
rowid = pd.Series(rowid, name = 'RowId')
loc = pd.Series(preded, name='Location')

# %%
submission = pd.concat([rowid, loc], axis=1)

# %%
submission.to_csv('submission_simple_model.csv', index=False)

# %% [markdown]
# ### 2.1.5 Results of Simple Model
#
# The simple 2 layer fully connected network achieves a Root Mean Squared Error of 3.96 on the competition. This is ranking 141 out of 175 competitors.
#
# I consider this a bad result, and judging by the plots of training and validation loss, the model does not overfit at all during training, even without any regularization.
#
# My next step will be to increase the complexity of the Fully Connected model, and regularize when appropriate.

# %% [markdown]
# ## 2.2 Training a Medium Complexity Model
#
# This time around, I'll be adding more layers to the FC model, and I will add regularization as I see appropriate from observing the behavior of the model during training.

# %%
def build_mid_model():
    """function that defines model with 6 hidden layers, and compiles it. 
    returns compiled model"""
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(9216,)))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(30))

    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    print(model.summary())
    return model

# %%
mid_model = build_mid_model()

mid_model_history = mid_model.fit(train_x, train_y, batch_size=32,
                           epochs=300, validation_split=0.2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 256)               2359552
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_23 (Dense)             (None, 30)                1950
# =================================================================
# Total params: 2,489,118
# Trainable params: 2,489,118
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 5639 samples, validate on 1410 samples
# Epoch 1/300
# 5639/5639 [==============================] - 2s 276us/step - loss: 3439.9252 - mean_absolute_error: 24.7580 - val_loss: 169.7922 - val_mean_absolute_error: 10.0033
# Epoch 2/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 253.6517 - mean_absolute_error: 12.2872 - val_loss: 274.9914 - val_mean_absolute_error: 13.7379
# Epoch 3/300
# 5639/5639 [==============================] - 1s 184us/step - loss: 220.4761 - mean_absolute_error: 11.3733 - val_loss: 576.2381 - val_mean_absolute_error: 21.5799
# Epoch 4/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 198.4820 - mean_absolute_error: 10.7823 - val_loss: 137.5730 - val_mean_absolute_error: 8.8387
# Epoch 5/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 179.4976 - mean_absolute_error: 10.2087 - val_loss: 416.5347 - val_mean_absolute_error: 18.0019
# Epoch 6/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 175.0220 - mean_absolute_error: 10.0620 - val_loss: 247.6988 - val_mean_absolute_error: 13.0774
# Epoch 7/300
# 5639/5639 [==============================] - 1s 187us/step - loss: 169.3694 - mean_absolute_error: 9.9075 - val_loss: 294.3095 - val_mean_absolute_error: 14.3556
# Epoch 8/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 166.4300 - mean_absolute_error: 9.8098 - val_loss: 257.6062 - val_mean_absolute_error: 13.3191
# Epoch 9/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 159.6630 - mean_absolute_error: 9.6219 - val_loss: 299.9321 - val_mean_absolute_error: 14.7475
# Epoch 10/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 155.1561 - mean_absolute_error: 9.4966 - val_loss: 239.3602 - val_mean_absolute_error: 12.7738
# Epoch 11/300
# 5639/5639 [==============================] - 1s 192us/step - loss: 150.0319 - mean_absolute_error: 9.2832 - val_loss: 612.4210 - val_mean_absolute_error: 22.6236
# Epoch 12/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 147.4010 - mean_absolute_error: 9.2047 - val_loss: 316.0453 - val_mean_absolute_error: 15.4031
# Epoch 13/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 147.0239 - mean_absolute_error: 9.1609 - val_loss: 475.9139 - val_mean_absolute_error: 19.6467
# Epoch 14/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 144.2006 - mean_absolute_error: 9.0810 - val_loss: 309.5847 - val_mean_absolute_error: 15.1288
# Epoch 15/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 143.0052 - mean_absolute_error: 9.0545 - val_loss: 291.3592 - val_mean_absolute_error: 14.5308
# Epoch 16/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 140.8163 - mean_absolute_error: 8.9884 - val_loss: 252.0801 - val_mean_absolute_error: 13.2892
# Epoch 17/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 134.5986 - mean_absolute_error: 8.7895 - val_loss: 204.0398 - val_mean_absolute_error: 11.5787
# Epoch 18/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 136.1345 - mean_absolute_error: 8.8209 - val_loss: 319.0473 - val_mean_absolute_error: 15.3227
# Epoch 19/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 130.5952 - mean_absolute_error: 8.6151 - val_loss: 93.3097 - val_mean_absolute_error: 7.2044
# Epoch 20/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 130.8651 - mean_absolute_error: 8.6656 - val_loss: 262.2350 - val_mean_absolute_error: 13.4982
# Epoch 21/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 128.6496 - mean_absolute_error: 8.5700 - val_loss: 272.3075 - val_mean_absolute_error: 14.0740
# Epoch 22/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 132.8848 - mean_absolute_error: 8.6886 - val_loss: 333.8704 - val_mean_absolute_error: 15.9462
# Epoch 23/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 130.8612 - mean_absolute_error: 8.6417 - val_loss: 656.1236 - val_mean_absolute_error: 23.4859
# Epoch 24/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 126.2746 - mean_absolute_error: 8.4724 - val_loss: 211.3537 - val_mean_absolute_error: 11.8974
# Epoch 25/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 126.0867 - mean_absolute_error: 8.5061 - val_loss: 157.8104 - val_mean_absolute_error: 9.8508
# Epoch 26/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 122.0993 - mean_absolute_error: 8.3169 - val_loss: 215.0496 - val_mean_absolute_error: 12.0048
# Epoch 27/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 122.7873 - mean_absolute_error: 8.3715 - val_loss: 195.3887 - val_mean_absolute_error: 11.3288
# Epoch 28/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 119.8882 - mean_absolute_error: 8.2549 - val_loss: 339.2189 - val_mean_absolute_error: 16.1335
# Epoch 29/300
# 5639/5639 [==============================] - 1s 185us/step - loss: 121.7667 - mean_absolute_error: 8.2884 - val_loss: 619.0708 - val_mean_absolute_error: 22.6915
# Epoch 30/300
# 5639/5639 [==============================] - 1s 184us/step - loss: 118.3893 - mean_absolute_error: 8.1899 - val_loss: 152.5487 - val_mean_absolute_error: 9.6703
# Epoch 31/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 120.2518 - mean_absolute_error: 8.2413 - val_loss: 164.2894 - val_mean_absolute_error: 10.2095
# Epoch 32/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 117.8515 - mean_absolute_error: 8.1252 - val_loss: 389.2553 - val_mean_absolute_error: 17.4834
# Epoch 33/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 116.6827 - mean_absolute_error: 8.1006 - val_loss: 198.4551 - val_mean_absolute_error: 11.4334
# Epoch 34/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 116.5128 - mean_absolute_error: 8.1197 - val_loss: 178.0857 - val_mean_absolute_error: 10.7179
# Epoch 35/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 111.9679 - mean_absolute_error: 7.9033 - val_loss: 86.8879 - val_mean_absolute_error: 6.9061
# Epoch 36/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 115.5843 - mean_absolute_error: 8.0893 - val_loss: 318.5433 - val_mean_absolute_error: 15.6974
# Epoch 37/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 111.8683 - mean_absolute_error: 7.9130 - val_loss: 204.6769 - val_mean_absolute_error: 11.8315
# Epoch 38/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 107.6167 - mean_absolute_error: 7.7577 - val_loss: 136.2122 - val_mean_absolute_error: 9.0074
# Epoch 39/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 110.8165 - mean_absolute_error: 7.8966 - val_loss: 349.7378 - val_mean_absolute_error: 16.4908
# Epoch 40/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 110.8691 - mean_absolute_error: 7.8854 - val_loss: 441.4822 - val_mean_absolute_error: 18.7796
# Epoch 41/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 107.2351 - mean_absolute_error: 7.7246 - val_loss: 148.4781 - val_mean_absolute_error: 9.5837
# Epoch 42/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 106.0743 - mean_absolute_error: 7.7208 - val_loss: 341.1643 - val_mean_absolute_error: 16.3397
# Epoch 43/300
# 5639/5639 [==============================] - 1s 186us/step - loss: 108.0857 - mean_absolute_error: 7.7563 - val_loss: 214.7168 - val_mean_absolute_error: 12.1689
# Epoch 44/300
# 5639/5639 [==============================] - 1s 191us/step - loss: 104.7846 - mean_absolute_error: 7.6333 - val_loss: 221.3906 - val_mean_absolute_error: 12.5143
# Epoch 45/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 105.1537 - mean_absolute_error: 7.6830 - val_loss: 222.8344 - val_mean_absolute_error: 12.5249
# Epoch 46/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 102.9356 - mean_absolute_error: 7.5468 - val_loss: 222.2169 - val_mean_absolute_error: 12.4559
# Epoch 47/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 104.7931 - mean_absolute_error: 7.6323 - val_loss: 305.5439 - val_mean_absolute_error: 15.2558
# Epoch 48/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 101.0456 - mean_absolute_error: 7.5035 - val_loss: 138.5622 - val_mean_absolute_error: 9.2548
# Epoch 49/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 101.3424 - mean_absolute_error: 7.5126 - val_loss: 250.0726 - val_mean_absolute_error: 13.3981
# Epoch 50/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 102.5120 - mean_absolute_error: 7.5445 - val_loss: 557.8527 - val_mean_absolute_error: 21.4898
# Epoch 51/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 100.6314 - mean_absolute_error: 7.4643 - val_loss: 327.9973 - val_mean_absolute_error: 15.7656
# Epoch 52/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 99.3323 - mean_absolute_error: 7.4676 - val_loss: 300.3483 - val_mean_absolute_error: 15.0659
# Epoch 53/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 97.0227 - mean_absolute_error: 7.3411 - val_loss: 214.8460 - val_mean_absolute_error: 12.2583
# Epoch 54/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 98.9396 - mean_absolute_error: 7.4303 - val_loss: 141.7570 - val_mean_absolute_error: 9.3591
# Epoch 55/300
# 5639/5639 [==============================] - 1s 187us/step - loss: 96.8996 - mean_absolute_error: 7.3190 - val_loss: 525.4315 - val_mean_absolute_error: 20.6563
# Epoch 56/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 97.4702 - mean_absolute_error: 7.3453 - val_loss: 279.1029 - val_mean_absolute_error: 14.5231
# Epoch 57/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 96.3900 - mean_absolute_error: 7.3025 - val_loss: 178.0581 - val_mean_absolute_error: 10.8993
# Epoch 58/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 98.3137 - mean_absolute_error: 7.3691 - val_loss: 254.1770 - val_mean_absolute_error: 13.6083
# Epoch 59/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 93.7160 - mean_absolute_error: 7.1817 - val_loss: 164.3739 - val_mean_absolute_error: 10.3957
# Epoch 60/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 94.5002 - mean_absolute_error: 7.2299 - val_loss: 193.2469 - val_mean_absolute_error: 11.5045
# Epoch 61/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 94.1227 - mean_absolute_error: 7.2470 - val_loss: 363.4529 - val_mean_absolute_error: 16.7352
# Epoch 62/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 94.2682 - mean_absolute_error: 7.1918 - val_loss: 199.5937 - val_mean_absolute_error: 11.6609
# Epoch 63/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 91.5360 - mean_absolute_error: 7.0865 - val_loss: 134.6023 - val_mean_absolute_error: 9.0008
# Epoch 64/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 91.0553 - mean_absolute_error: 7.0628 - val_loss: 117.7616 - val_mean_absolute_error: 8.2638
# Epoch 65/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 90.1268 - mean_absolute_error: 7.0251 - val_loss: 176.9359 - val_mean_absolute_error: 10.8084
# Epoch 66/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 92.0522 - mean_absolute_error: 7.1156 - val_loss: 132.9168 - val_mean_absolute_error: 8.9996
# Epoch 67/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 90.8158 - mean_absolute_error: 7.0623 - val_loss: 285.1853 - val_mean_absolute_error: 14.5796
# Epoch 68/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 87.3644 - mean_absolute_error: 6.9386 - val_loss: 490.1738 - val_mean_absolute_error: 19.9022
# Epoch 69/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 87.7077 - mean_absolute_error: 6.9063 - val_loss: 253.3797 - val_mean_absolute_error: 13.7012
# Epoch 70/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 86.8908 - mean_absolute_error: 6.9276 - val_loss: 347.2561 - val_mean_absolute_error: 16.4573
# Epoch 71/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 87.5487 - mean_absolute_error: 6.9219 - val_loss: 226.5987 - val_mean_absolute_error: 12.7410
# Epoch 72/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 87.3455 - mean_absolute_error: 6.9249 - val_loss: 421.0103 - val_mean_absolute_error: 18.3452
# Epoch 73/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 85.1069 - mean_absolute_error: 6.8247 - val_loss: 177.3641 - val_mean_absolute_error: 10.9540
# Epoch 74/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 84.9907 - mean_absolute_error: 6.8371 - val_loss: 323.4972 - val_mean_absolute_error: 15.8511
# Epoch 75/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 84.1478 - mean_absolute_error: 6.7558 - val_loss: 324.0745 - val_mean_absolute_error: 15.7591
# Epoch 76/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 83.3131 - mean_absolute_error: 6.7301 - val_loss: 439.5627 - val_mean_absolute_error: 18.8712
# Epoch 77/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 83.4366 - mean_absolute_error: 6.7473 - val_loss: 297.5615 - val_mean_absolute_error: 15.0613
# Epoch 78/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 84.9842 - mean_absolute_error: 6.7957 - val_loss: 401.7948 - val_mean_absolute_error: 17.9155
# Epoch 79/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 83.4874 - mean_absolute_error: 6.7562 - val_loss: 239.1692 - val_mean_absolute_error: 13.2248
# Epoch 80/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 83.5455 - mean_absolute_error: 6.7331 - val_loss: 170.1157 - val_mean_absolute_error: 10.7256
# Epoch 81/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 82.7809 - mean_absolute_error: 6.7177 - val_loss: 292.0608 - val_mean_absolute_error: 14.8963
# Epoch 82/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 81.2338 - mean_absolute_error: 6.6264 - val_loss: 251.9698 - val_mean_absolute_error: 13.6774
# Epoch 83/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 82.2132 - mean_absolute_error: 6.7162 - val_loss: 492.4806 - val_mean_absolute_error: 20.0215
# Epoch 84/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 80.6538 - mean_absolute_error: 6.6106 - val_loss: 326.2676 - val_mean_absolute_error: 15.9064
# Epoch 85/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 79.7803 - mean_absolute_error: 6.6098 - val_loss: 228.3023 - val_mean_absolute_error: 12.8399
# Epoch 86/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 78.3461 - mean_absolute_error: 6.5228 - val_loss: 265.8918 - val_mean_absolute_error: 14.1731
# Epoch 87/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 77.8609 - mean_absolute_error: 6.4996 - val_loss: 150.6747 - val_mean_absolute_error: 9.8882
# Epoch 88/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 77.0907 - mean_absolute_error: 6.4687 - val_loss: 244.9841 - val_mean_absolute_error: 13.3928
# Epoch 89/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 78.0851 - mean_absolute_error: 6.4997 - val_loss: 180.5255 - val_mean_absolute_error: 11.1632
# Epoch 90/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 77.0043 - mean_absolute_error: 6.4768 - val_loss: 235.5473 - val_mean_absolute_error: 13.2061
# Epoch 91/300
# 5639/5639 [==============================] - 1s 185us/step - loss: 75.8799 - mean_absolute_error: 6.4296 - val_loss: 363.5894 - val_mean_absolute_error: 16.9716
# Epoch 92/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 73.9995 - mean_absolute_error: 6.3563 - val_loss: 104.8984 - val_mean_absolute_error: 7.8403
# Epoch 93/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 76.4209 - mean_absolute_error: 6.4513 - val_loss: 163.5758 - val_mean_absolute_error: 10.5510
# Epoch 94/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 75.8709 - mean_absolute_error: 6.3877 - val_loss: 322.6133 - val_mean_absolute_error: 15.8569
# Epoch 95/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 73.9688 - mean_absolute_error: 6.2831 - val_loss: 199.2471 - val_mean_absolute_error: 11.8899
# Epoch 96/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 73.6187 - mean_absolute_error: 6.3040 - val_loss: 314.5131 - val_mean_absolute_error: 15.6268
# Epoch 97/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 71.8407 - mean_absolute_error: 6.2462 - val_loss: 258.4297 - val_mean_absolute_error: 13.9597
# Epoch 98/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 70.7026 - mean_absolute_error: 6.1904 - val_loss: 180.1313 - val_mean_absolute_error: 11.2193
# Epoch 99/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 72.1459 - mean_absolute_error: 6.1465 - val_loss: 189.4093 - val_mean_absolute_error: 11.5403
# Epoch 100/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 69.9458 - mean_absolute_error: 6.1239 - val_loss: 192.3876 - val_mean_absolute_error: 11.7147
# Epoch 101/300
# 5639/5639 [==============================] - 1s 181us/step - loss: 64.4296 - mean_absolute_error: 5.8582 - val_loss: 337.0271 - val_mean_absolute_error: 16.2598
# Epoch 102/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 64.2689 - mean_absolute_error: 5.8932 - val_loss: 111.8354 - val_mean_absolute_error: 8.2506
# Epoch 103/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 63.8593 - mean_absolute_error: 5.8550 - val_loss: 199.4117 - val_mean_absolute_error: 12.0653
# Epoch 104/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 61.8048 - mean_absolute_error: 5.7489 - val_loss: 172.2667 - val_mean_absolute_error: 11.0026
# Epoch 105/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 59.7617 - mean_absolute_error: 5.6779 - val_loss: 352.5451 - val_mean_absolute_error: 16.7343
# Epoch 106/300
# 5639/5639 [==============================] - 1s 164us/step - loss: 58.6141 - mean_absolute_error: 5.6000 - val_loss: 258.0566 - val_mean_absolute_error: 14.0497
# Epoch 107/300
# 5639/5639 [==============================] - 1s 164us/step - loss: 56.1281 - mean_absolute_error: 5.4802 - val_loss: 151.4107 - val_mean_absolute_error: 10.2212
# Epoch 108/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 55.8893 - mean_absolute_error: 5.4445 - val_loss: 140.3725 - val_mean_absolute_error: 9.7517
# Epoch 109/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 51.9169 - mean_absolute_error: 5.2406 - val_loss: 256.1300 - val_mean_absolute_error: 14.0582
# Epoch 110/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 52.3534 - mean_absolute_error: 5.2540 - val_loss: 117.5063 - val_mean_absolute_error: 8.7734
# Epoch 111/300
# 5639/5639 [==============================] - 1s 163us/step - loss: 48.9740 - mean_absolute_error: 5.0871 - val_loss: 167.2417 - val_mean_absolute_error: 10.9416
# Epoch 112/300
# 5639/5639 [==============================] - 1s 165us/step - loss: 49.7200 - mean_absolute_error: 5.1209 - val_loss: 119.5856 - val_mean_absolute_error: 8.9167
# Epoch 113/300
# 5639/5639 [==============================] - 1s 165us/step - loss: 46.7687 - mean_absolute_error: 4.9386 - val_loss: 117.1332 - val_mean_absolute_error: 8.8924
# Epoch 114/300
# 5639/5639 [==============================] - 1s 164us/step - loss: 43.3629 - mean_absolute_error: 4.8037 - val_loss: 304.7074 - val_mean_absolute_error: 15.4396
# Epoch 115/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 42.1368 - mean_absolute_error: 4.6877 - val_loss: 58.3691 - val_mean_absolute_error: 5.6539
# Epoch 116/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 40.4527 - mean_absolute_error: 4.5836 - val_loss: 118.4419 - val_mean_absolute_error: 8.9993
# Epoch 117/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 37.5982 - mean_absolute_error: 4.4170 - val_loss: 64.1439 - val_mean_absolute_error: 6.0949
# Epoch 118/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 35.5757 - mean_absolute_error: 4.2994 - val_loss: 100.4386 - val_mean_absolute_error: 8.1926
# Epoch 119/300
# 5639/5639 [==============================] - 1s 164us/step - loss: 33.7649 - mean_absolute_error: 4.1668 - val_loss: 95.3005 - val_mean_absolute_error: 7.9478
# Epoch 120/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 31.0767 - mean_absolute_error: 3.9764 - val_loss: 74.4925 - val_mean_absolute_error: 6.8333
# Epoch 121/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 28.8872 - mean_absolute_error: 3.8149 - val_loss: 131.4190 - val_mean_absolute_error: 9.6719
# Epoch 122/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 27.3256 - mean_absolute_error: 3.7187 - val_loss: 94.2815 - val_mean_absolute_error: 7.9766
# Epoch 123/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 25.1780 - mean_absolute_error: 3.5290 - val_loss: 36.4042 - val_mean_absolute_error: 4.3658
# Epoch 124/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 23.4257 - mean_absolute_error: 3.3954 - val_loss: 46.3416 - val_mean_absolute_error: 5.1502
# Epoch 125/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 20.7551 - mean_absolute_error: 3.1692 - val_loss: 51.3880 - val_mean_absolute_error: 5.5997
# Epoch 126/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 18.4886 - mean_absolute_error: 2.9681 - val_loss: 32.9589 - val_mean_absolute_error: 4.2378
# Epoch 127/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 16.8665 - mean_absolute_error: 2.8056 - val_loss: 35.9561 - val_mean_absolute_error: 4.4826
# Epoch 128/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 14.7712 - mean_absolute_error: 2.5848 - val_loss: 44.2302 - val_mean_absolute_error: 5.0782
# Epoch 129/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 13.5932 - mean_absolute_error: 2.3922 - val_loss: 33.0134 - val_mean_absolute_error: 4.3252
# Epoch 130/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 11.5805 - mean_absolute_error: 2.1748 - val_loss: 12.7866 - val_mean_absolute_error: 2.2513
# Epoch 131/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 10.1753 - mean_absolute_error: 2.0116 - val_loss: 15.2251 - val_mean_absolute_error: 2.6051
# Epoch 132/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 12.1447 - mean_absolute_error: 1.8672 - val_loss: 13.9177 - val_mean_absolute_error: 2.4813
# Epoch 133/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 8.4075 - mean_absolute_error: 1.7192 - val_loss: 9.6171 - val_mean_absolute_error: 1.8273
# Epoch 134/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 8.0653 - mean_absolute_error: 1.6109 - val_loss: 10.2483 - val_mean_absolute_error: 1.9967
# Epoch 135/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 7.5622 - mean_absolute_error: 1.5173 - val_loss: 9.3860 - val_mean_absolute_error: 1.7787
# Epoch 136/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 7.4372 - mean_absolute_error: 1.4663 - val_loss: 8.3021 - val_mean_absolute_error: 1.5784
# Epoch 137/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 7.3090 - mean_absolute_error: 1.4412 - val_loss: 8.5133 - val_mean_absolute_error: 1.6381
# Epoch 138/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 7.2881 - mean_absolute_error: 1.4340 - val_loss: 8.3165 - val_mean_absolute_error: 1.5489
# Epoch 139/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 7.2560 - mean_absolute_error: 1.4274 - val_loss: 8.1081 - val_mean_absolute_error: 1.4619
# Epoch 140/300
# 5639/5639 [==============================] - 1s 165us/step - loss: 7.1427 - mean_absolute_error: 1.4212 - val_loss: 7.9496 - val_mean_absolute_error: 1.4338
# Epoch 141/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 7.1524 - mean_absolute_error: 1.4213 - val_loss: 8.4313 - val_mean_absolute_error: 1.6345
# Epoch 142/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 7.1645 - mean_absolute_error: 1.4281 - val_loss: 7.8124 - val_mean_absolute_error: 1.3953
# Epoch 143/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 7.0468 - mean_absolute_error: 1.4128 - val_loss: 7.8366 - val_mean_absolute_error: 1.4558
# Epoch 144/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 7.0169 - mean_absolute_error: 1.4037 - val_loss: 7.7031 - val_mean_absolute_error: 1.3908
# Epoch 145/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.9876 - mean_absolute_error: 1.4002 - val_loss: 7.8890 - val_mean_absolute_error: 1.4023
# Epoch 146/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 7.0182 - mean_absolute_error: 1.4083 - val_loss: 7.7515 - val_mean_absolute_error: 1.4173
# Epoch 147/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 6.9618 - mean_absolute_error: 1.4011 - val_loss: 7.7072 - val_mean_absolute_error: 1.4456
# Epoch 148/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.9315 - mean_absolute_error: 1.4012 - val_loss: 7.8002 - val_mean_absolute_error: 1.4024
# Epoch 149/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.9630 - mean_absolute_error: 1.3948 - val_loss: 7.6544 - val_mean_absolute_error: 1.3946
# Epoch 150/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.9016 - mean_absolute_error: 1.3950 - val_loss: 7.8051 - val_mean_absolute_error: 1.4851
# Epoch 151/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.9910 - mean_absolute_error: 1.4021 - val_loss: 7.7682 - val_mean_absolute_error: 1.4402
# Epoch 152/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.9637 - mean_absolute_error: 1.3914 - val_loss: 7.7001 - val_mean_absolute_error: 1.3686
# Epoch 153/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.8678 - mean_absolute_error: 1.3901 - val_loss: 7.7295 - val_mean_absolute_error: 1.4623
# Epoch 154/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.8423 - mean_absolute_error: 1.3828 - val_loss: 7.6677 - val_mean_absolute_error: 1.3888
# Epoch 155/300
# 5639/5639 [==============================] - 1s 162us/step - loss: 6.8824 - mean_absolute_error: 1.3862 - val_loss: 7.7542 - val_mean_absolute_error: 1.4219
# Epoch 156/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 6.8975 - mean_absolute_error: 1.3848 - val_loss: 7.5278 - val_mean_absolute_error: 1.3782
# Epoch 157/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.8402 - mean_absolute_error: 1.3840 - val_loss: 7.4667 - val_mean_absolute_error: 1.3668
# Epoch 158/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 6.8657 - mean_absolute_error: 1.3866 - val_loss: 8.6319 - val_mean_absolute_error: 1.6598
# Epoch 159/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.8076 - mean_absolute_error: 1.3795 - val_loss: 7.8816 - val_mean_absolute_error: 1.4876
# Epoch 160/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.8567 - mean_absolute_error: 1.3806 - val_loss: 7.8474 - val_mean_absolute_error: 1.5002
# Epoch 161/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 7.6118 - mean_absolute_error: 1.3982 - val_loss: 7.4791 - val_mean_absolute_error: 1.3562
# Epoch 162/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.7692 - mean_absolute_error: 1.3724 - val_loss: 7.7929 - val_mean_absolute_error: 1.4209
# Epoch 163/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.8050 - mean_absolute_error: 1.3786 - val_loss: 8.0215 - val_mean_absolute_error: 1.5656
# Epoch 164/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 6.7930 - mean_absolute_error: 1.3753 - val_loss: 7.4223 - val_mean_absolute_error: 1.3678
# Epoch 165/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.7535 - mean_absolute_error: 1.3774 - val_loss: 7.7319 - val_mean_absolute_error: 1.4774
# Epoch 166/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 6.8073 - mean_absolute_error: 1.3760 - val_loss: 8.9599 - val_mean_absolute_error: 1.6913
# Epoch 167/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.7655 - mean_absolute_error: 1.3733 - val_loss: 7.8166 - val_mean_absolute_error: 1.5027
# Epoch 168/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.7470 - mean_absolute_error: 1.3685 - val_loss: 7.7278 - val_mean_absolute_error: 1.4760
# Epoch 169/300
# 5639/5639 [==============================] - 1s 186us/step - loss: 6.7954 - mean_absolute_error: 1.3709 - val_loss: 7.8431 - val_mean_absolute_error: 1.4614
# Epoch 170/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.7583 - mean_absolute_error: 1.3648 - val_loss: 7.6544 - val_mean_absolute_error: 1.4555
# Epoch 171/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.7080 - mean_absolute_error: 1.3637 - val_loss: 7.4205 - val_mean_absolute_error: 1.3696
# Epoch 172/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.6857 - mean_absolute_error: 1.3634 - val_loss: 7.5388 - val_mean_absolute_error: 1.3911
# Epoch 173/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 6.6810 - mean_absolute_error: 1.3612 - val_loss: 7.4492 - val_mean_absolute_error: 1.3941
# Epoch 174/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.6729 - mean_absolute_error: 1.3579 - val_loss: 8.0713 - val_mean_absolute_error: 1.5417
# Epoch 175/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.6504 - mean_absolute_error: 1.3544 - val_loss: 8.1179 - val_mean_absolute_error: 1.5951
# Epoch 176/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.6684 - mean_absolute_error: 1.3558 - val_loss: 7.4217 - val_mean_absolute_error: 1.3597
# Epoch 177/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.7291 - mean_absolute_error: 1.3588 - val_loss: 7.4035 - val_mean_absolute_error: 1.3618
# Epoch 178/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.6573 - mean_absolute_error: 1.3478 - val_loss: 7.4612 - val_mean_absolute_error: 1.4109
# Epoch 179/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.6479 - mean_absolute_error: 1.3548 - val_loss: 7.5538 - val_mean_absolute_error: 1.4343
# Epoch 180/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.6101 - mean_absolute_error: 1.3480 - val_loss: 7.4916 - val_mean_absolute_error: 1.3715
# Epoch 181/300
# 5639/5639 [==============================] - 1s 163us/step - loss: 6.6904 - mean_absolute_error: 1.3574 - val_loss: 7.3606 - val_mean_absolute_error: 1.3523
# Epoch 182/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.6396 - mean_absolute_error: 1.3464 - val_loss: 7.4882 - val_mean_absolute_error: 1.3445
# Epoch 183/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.5809 - mean_absolute_error: 1.3436 - val_loss: 7.6949 - val_mean_absolute_error: 1.4035
# Epoch 184/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.5789 - mean_absolute_error: 1.3462 - val_loss: 7.4575 - val_mean_absolute_error: 1.3737
# Epoch 185/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.5887 - mean_absolute_error: 1.3422 - val_loss: 7.5501 - val_mean_absolute_error: 1.3784
# Epoch 186/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.5715 - mean_absolute_error: 1.3438 - val_loss: 7.5138 - val_mean_absolute_error: 1.3975
# Epoch 187/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.6343 - mean_absolute_error: 1.3499 - val_loss: 7.5921 - val_mean_absolute_error: 1.3952
# Epoch 188/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.5807 - mean_absolute_error: 1.3425 - val_loss: 7.3385 - val_mean_absolute_error: 1.3770
# Epoch 189/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.5679 - mean_absolute_error: 1.3457 - val_loss: 7.3225 - val_mean_absolute_error: 1.3631
# Epoch 190/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.5597 - mean_absolute_error: 1.3405 - val_loss: 7.6342 - val_mean_absolute_error: 1.4303
# Epoch 191/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.6454 - mean_absolute_error: 1.3459 - val_loss: 7.8039 - val_mean_absolute_error: 1.4530
# Epoch 192/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.5832 - mean_absolute_error: 1.3456 - val_loss: 7.3845 - val_mean_absolute_error: 1.3542
# Epoch 193/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.5531 - mean_absolute_error: 1.3402 - val_loss: 7.4842 - val_mean_absolute_error: 1.3760
# Epoch 194/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.5745 - mean_absolute_error: 1.3422 - val_loss: 7.2855 - val_mean_absolute_error: 1.3587
# Epoch 195/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 6.5366 - mean_absolute_error: 1.3372 - val_loss: 7.3533 - val_mean_absolute_error: 1.3933
# Epoch 196/300
# 5639/5639 [==============================] - 1s 176us/step - loss: 6.5712 - mean_absolute_error: 1.3405 - val_loss: 8.2637 - val_mean_absolute_error: 1.5792
# Epoch 197/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.7554 - mean_absolute_error: 1.3560 - val_loss: 7.4080 - val_mean_absolute_error: 1.3619
# Epoch 198/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 7.0595 - mean_absolute_error: 1.3549 - val_loss: 7.2500 - val_mean_absolute_error: 1.3370
# Epoch 199/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.5213 - mean_absolute_error: 1.3386 - val_loss: 7.3686 - val_mean_absolute_error: 1.3597
# Epoch 200/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.5162 - mean_absolute_error: 1.3349 - val_loss: 7.4480 - val_mean_absolute_error: 1.3938
# Epoch 201/300
# 5639/5639 [==============================] - 1s 184us/step - loss: 6.5289 - mean_absolute_error: 1.3387 - val_loss: 7.3225 - val_mean_absolute_error: 1.3636
# Epoch 202/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.5182 - mean_absolute_error: 1.3350 - val_loss: 7.5904 - val_mean_absolute_error: 1.4220
# Epoch 203/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.5137 - mean_absolute_error: 1.3345 - val_loss: 7.7434 - val_mean_absolute_error: 1.4704
# Epoch 204/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.5567 - mean_absolute_error: 1.3365 - val_loss: 7.4061 - val_mean_absolute_error: 1.3875
# Epoch 205/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.5531 - mean_absolute_error: 1.3380 - val_loss: 7.4726 - val_mean_absolute_error: 1.3970
# Epoch 206/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.5166 - mean_absolute_error: 1.3353 - val_loss: 7.8219 - val_mean_absolute_error: 1.5157
# Epoch 207/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.5056 - mean_absolute_error: 1.3330 - val_loss: 7.3863 - val_mean_absolute_error: 1.3914
# Epoch 208/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.5306 - mean_absolute_error: 1.3352 - val_loss: 7.3295 - val_mean_absolute_error: 1.3395
# Epoch 209/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4398 - mean_absolute_error: 1.3279 - val_loss: 7.4021 - val_mean_absolute_error: 1.3890
# Epoch 210/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.9003 - mean_absolute_error: 1.3358 - val_loss: 7.4793 - val_mean_absolute_error: 1.3939
# Epoch 211/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 6.5279 - mean_absolute_error: 1.3401 - val_loss: 7.2800 - val_mean_absolute_error: 1.3529
# Epoch 212/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.5176 - mean_absolute_error: 1.3336 - val_loss: 7.2623 - val_mean_absolute_error: 1.3545
# Epoch 213/300
# 5639/5639 [==============================] - 1s 185us/step - loss: 6.4582 - mean_absolute_error: 1.3286 - val_loss: 7.4594 - val_mean_absolute_error: 1.3811
# Epoch 214/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4901 - mean_absolute_error: 1.3316 - val_loss: 7.3262 - val_mean_absolute_error: 1.3771
# Epoch 215/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.5023 - mean_absolute_error: 1.3313 - val_loss: 7.3838 - val_mean_absolute_error: 1.3591
# Epoch 216/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.4565 - mean_absolute_error: 1.3272 - val_loss: 7.4719 - val_mean_absolute_error: 1.3755
# Epoch 217/300
# 5639/5639 [==============================] - 1s 177us/step - loss: 6.4538 - mean_absolute_error: 1.3289 - val_loss: 7.3545 - val_mean_absolute_error: 1.3711
# Epoch 218/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.5063 - mean_absolute_error: 1.3327 - val_loss: 7.2939 - val_mean_absolute_error: 1.3267
# Epoch 219/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.4334 - mean_absolute_error: 1.3269 - val_loss: 7.2726 - val_mean_absolute_error: 1.3979
# Epoch 220/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.5077 - mean_absolute_error: 1.3310 - val_loss: 7.3630 - val_mean_absolute_error: 1.3914
# Epoch 221/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.4797 - mean_absolute_error: 1.3283 - val_loss: 7.3986 - val_mean_absolute_error: 1.3546
# Epoch 222/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.4370 - mean_absolute_error: 1.3263 - val_loss: 7.1594 - val_mean_absolute_error: 1.3598
# Epoch 223/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.4605 - mean_absolute_error: 1.3260 - val_loss: 7.4691 - val_mean_absolute_error: 1.3611
# Epoch 224/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.4673 - mean_absolute_error: 1.3203 - val_loss: 7.2312 - val_mean_absolute_error: 1.3434
# Epoch 225/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.4376 - mean_absolute_error: 1.3258 - val_loss: 8.0107 - val_mean_absolute_error: 1.5186
# Epoch 226/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.5931 - mean_absolute_error: 1.3374 - val_loss: 7.2918 - val_mean_absolute_error: 1.3179
# Epoch 227/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4994 - mean_absolute_error: 1.3288 - val_loss: 7.4014 - val_mean_absolute_error: 1.3459
# Epoch 228/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4418 - mean_absolute_error: 1.3283 - val_loss: 7.2714 - val_mean_absolute_error: 1.3601
# Epoch 229/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.7071 - mean_absolute_error: 1.3583 - val_loss: 7.5283 - val_mean_absolute_error: 1.4193
# Epoch 230/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4421 - mean_absolute_error: 1.3314 - val_loss: 7.4088 - val_mean_absolute_error: 1.4142
# Epoch 231/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.4472 - mean_absolute_error: 1.3298 - val_loss: 7.4479 - val_mean_absolute_error: 1.3843
# Epoch 232/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.4729 - mean_absolute_error: 1.3301 - val_loss: 7.2772 - val_mean_absolute_error: 1.3337
# Epoch 233/300
# 5639/5639 [==============================] - 1s 178us/step - loss: 6.4739 - mean_absolute_error: 1.3313 - val_loss: 7.7923 - val_mean_absolute_error: 1.4704
# Epoch 234/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.4582 - mean_absolute_error: 1.3331 - val_loss: 7.4201 - val_mean_absolute_error: 1.3953
# Epoch 235/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.4786 - mean_absolute_error: 1.3306 - val_loss: 7.3723 - val_mean_absolute_error: 1.3354
# Epoch 236/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.4727 - mean_absolute_error: 1.3305 - val_loss: 7.1963 - val_mean_absolute_error: 1.3481
# Epoch 237/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.4351 - mean_absolute_error: 1.3294 - val_loss: 7.2768 - val_mean_absolute_error: 1.3668
# Epoch 238/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.4152 - mean_absolute_error: 1.3261 - val_loss: 7.2079 - val_mean_absolute_error: 1.3351
# Epoch 239/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.4101 - mean_absolute_error: 1.3251 - val_loss: 7.4040 - val_mean_absolute_error: 1.3741
# Epoch 240/300
# 5639/5639 [==============================] - 1s 163us/step - loss: 6.4382 - mean_absolute_error: 1.3238 - val_loss: 7.0964 - val_mean_absolute_error: 1.3232
# Epoch 241/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.4170 - mean_absolute_error: 1.3271 - val_loss: 7.2014 - val_mean_absolute_error: 1.3508
# Epoch 242/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.4193 - mean_absolute_error: 1.3290 - val_loss: 7.3529 - val_mean_absolute_error: 1.3459
# Epoch 243/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.3824 - mean_absolute_error: 1.3203 - val_loss: 7.1555 - val_mean_absolute_error: 1.3490
# Epoch 244/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.3738 - mean_absolute_error: 1.3264 - val_loss: 7.2937 - val_mean_absolute_error: 1.3284
# Epoch 245/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.3678 - mean_absolute_error: 1.3219 - val_loss: 7.1503 - val_mean_absolute_error: 1.3509
# Epoch 246/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.3430 - mean_absolute_error: 1.3218 - val_loss: 7.2988 - val_mean_absolute_error: 1.3737
# Epoch 247/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.2961 - mean_absolute_error: 1.3181 - val_loss: 7.6260 - val_mean_absolute_error: 1.4212
# Epoch 248/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.3015 - mean_absolute_error: 1.3154 - val_loss: 7.1870 - val_mean_absolute_error: 1.3690
# Epoch 249/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.3283 - mean_absolute_error: 1.3262 - val_loss: 7.4983 - val_mean_absolute_error: 1.3485
# Epoch 250/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.2746 - mean_absolute_error: 1.3117 - val_loss: 7.0537 - val_mean_absolute_error: 1.3217
# Epoch 251/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.3002 - mean_absolute_error: 1.3187 - val_loss: 6.9789 - val_mean_absolute_error: 1.3153
# Epoch 252/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.2615 - mean_absolute_error: 1.3141 - val_loss: 7.2252 - val_mean_absolute_error: 1.3508
# Epoch 253/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.3030 - mean_absolute_error: 1.3212 - val_loss: 7.2160 - val_mean_absolute_error: 1.3422
# Epoch 254/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.2380 - mean_absolute_error: 1.3086 - val_loss: 7.2463 - val_mean_absolute_error: 1.3667
# Epoch 255/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.2690 - mean_absolute_error: 1.3195 - val_loss: 7.2398 - val_mean_absolute_error: 1.3905
# Epoch 256/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.2097 - mean_absolute_error: 1.3116 - val_loss: 7.4812 - val_mean_absolute_error: 1.3923
# Epoch 257/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.2288 - mean_absolute_error: 1.3135 - val_loss: 6.9772 - val_mean_absolute_error: 1.3078
# Epoch 258/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.2063 - mean_absolute_error: 1.3060 - val_loss: 7.1583 - val_mean_absolute_error: 1.3641
# Epoch 259/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.2162 - mean_absolute_error: 1.3094 - val_loss: 7.3508 - val_mean_absolute_error: 1.3865
# Epoch 260/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.2431 - mean_absolute_error: 1.3208 - val_loss: 7.3046 - val_mean_absolute_error: 1.4234
# Epoch 261/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.3728 - mean_absolute_error: 1.3155 - val_loss: 7.3433 - val_mean_absolute_error: 1.4237
# Epoch 262/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.1904 - mean_absolute_error: 1.3099 - val_loss: 7.2894 - val_mean_absolute_error: 1.3780
# Epoch 263/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.2916 - mean_absolute_error: 1.3194 - val_loss: 7.0179 - val_mean_absolute_error: 1.3350
# Epoch 264/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.1795 - mean_absolute_error: 1.3022 - val_loss: 7.3338 - val_mean_absolute_error: 1.4173
# Epoch 265/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.2074 - mean_absolute_error: 1.3164 - val_loss: 7.2930 - val_mean_absolute_error: 1.3872
# Epoch 266/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.2404 - mean_absolute_error: 1.3091 - val_loss: 7.0489 - val_mean_absolute_error: 1.3532
# Epoch 267/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.2075 - mean_absolute_error: 1.3126 - val_loss: 7.3022 - val_mean_absolute_error: 1.4256
# Epoch 268/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.2253 - mean_absolute_error: 1.3130 - val_loss: 7.1885 - val_mean_absolute_error: 1.3731
# Epoch 269/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.1872 - mean_absolute_error: 1.3102 - val_loss: 7.0010 - val_mean_absolute_error: 1.3332
# Epoch 270/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.1668 - mean_absolute_error: 1.3056 - val_loss: 7.2888 - val_mean_absolute_error: 1.4764
# Epoch 271/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.1949 - mean_absolute_error: 1.3120 - val_loss: 6.9869 - val_mean_absolute_error: 1.3103
# Epoch 272/300
# 5639/5639 [==============================] - 1s 174us/step - loss: 6.1782 - mean_absolute_error: 1.3073 - val_loss: 7.1407 - val_mean_absolute_error: 1.4472
# Epoch 273/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.1855 - mean_absolute_error: 1.3103 - val_loss: 7.2315 - val_mean_absolute_error: 1.3720
# Epoch 274/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.2008 - mean_absolute_error: 1.3152 - val_loss: 7.4140 - val_mean_absolute_error: 1.4404
# Epoch 275/300
# 5639/5639 [==============================] - 1s 182us/step - loss: 6.1834 - mean_absolute_error: 1.3132 - val_loss: 6.8683 - val_mean_absolute_error: 1.3076
# Epoch 276/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.1620 - mean_absolute_error: 1.3090 - val_loss: 7.0033 - val_mean_absolute_error: 1.3416
# Epoch 277/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.0934 - mean_absolute_error: 1.3044 - val_loss: 6.9275 - val_mean_absolute_error: 1.3485
# Epoch 278/300
# 5639/5639 [==============================] - 1s 165us/step - loss: 6.1738 - mean_absolute_error: 1.3107 - val_loss: 7.0178 - val_mean_absolute_error: 1.3510
# Epoch 279/300
# 5639/5639 [==============================] - 1s 172us/step - loss: 6.1397 - mean_absolute_error: 1.3077 - val_loss: 7.0877 - val_mean_absolute_error: 1.3097
# Epoch 280/300
# 5639/5639 [==============================] - 1s 163us/step - loss: 6.1678 - mean_absolute_error: 1.3080 - val_loss: 7.1317 - val_mean_absolute_error: 1.3496
# Epoch 281/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.1623 - mean_absolute_error: 1.3090 - val_loss: 7.7047 - val_mean_absolute_error: 1.4568
# Epoch 282/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.1261 - mean_absolute_error: 1.3088 - val_loss: 7.0752 - val_mean_absolute_error: 1.3523
# Epoch 283/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.1434 - mean_absolute_error: 1.3052 - val_loss: 6.9660 - val_mean_absolute_error: 1.3238
# Epoch 284/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.1038 - mean_absolute_error: 1.3083 - val_loss: 6.9873 - val_mean_absolute_error: 1.3326
# Epoch 285/300
# 5639/5639 [==============================] - 1s 173us/step - loss: 6.0788 - mean_absolute_error: 1.3027 - val_loss: 6.9406 - val_mean_absolute_error: 1.3455
# Epoch 286/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.0929 - mean_absolute_error: 1.3007 - val_loss: 7.0614 - val_mean_absolute_error: 1.3423
# Epoch 287/300
# 5639/5639 [==============================] - 1s 175us/step - loss: 6.1328 - mean_absolute_error: 1.3029 - val_loss: 7.1510 - val_mean_absolute_error: 1.3575
# Epoch 288/300
# 5639/5639 [==============================] - 1s 171us/step - loss: 6.1614 - mean_absolute_error: 1.3097 - val_loss: 7.0941 - val_mean_absolute_error: 1.3510
# Epoch 289/300
# 5639/5639 [==============================] - 1s 165us/step - loss: 6.1127 - mean_absolute_error: 1.3035 - val_loss: 7.0766 - val_mean_absolute_error: 1.3593
# Epoch 290/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.1043 - mean_absolute_error: 1.3061 - val_loss: 6.8856 - val_mean_absolute_error: 1.3250
# Epoch 291/300
# 5639/5639 [==============================] - 1s 169us/step - loss: 6.0754 - mean_absolute_error: 1.3039 - val_loss: 6.8775 - val_mean_absolute_error: 1.3421
# Epoch 292/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.0714 - mean_absolute_error: 1.2977 - val_loss: 6.9003 - val_mean_absolute_error: 1.3433
# Epoch 293/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.0604 - mean_absolute_error: 1.2999 - val_loss: 6.9034 - val_mean_absolute_error: 1.3255
# Epoch 294/300
# 5639/5639 [==============================] - 1s 167us/step - loss: 6.1142 - mean_absolute_error: 1.3048 - val_loss: 7.0010 - val_mean_absolute_error: 1.3546
# Epoch 295/300
# 5639/5639 [==============================] - 1s 179us/step - loss: 6.0138 - mean_absolute_error: 1.3001 - val_loss: 7.0394 - val_mean_absolute_error: 1.3798
# Epoch 296/300
# 5639/5639 [==============================] - 1s 180us/step - loss: 6.0763 - mean_absolute_error: 1.3003 - val_loss: 6.9436 - val_mean_absolute_error: 1.3308
# Epoch 297/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.0651 - mean_absolute_error: 1.3020 - val_loss: 6.8578 - val_mean_absolute_error: 1.3170
# Epoch 298/300
# 5639/5639 [==============================] - 1s 168us/step - loss: 6.0690 - mean_absolute_error: 1.2982 - val_loss: 7.1337 - val_mean_absolute_error: 1.3589
# Epoch 299/300
# 5639/5639 [==============================] - 1s 170us/step - loss: 6.0757 - mean_absolute_error: 1.3004 - val_loss: 7.1390 - val_mean_absolute_error: 1.3391
# Epoch 300/300
# 5639/5639 [==============================] - 1s 166us/step - loss: 6.1082 - mean_absolute_error: 1.3080 - val_loss: 6.9411 - val_mean_absolute_error: 1.3256

# %%
loss = mid_model_history.history['loss'][3:]
val_loss = mid_model_history.history['val_loss'][3:]

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = mid_model_history.history['mean_absolute_error'][3:]
val_mae = mid_model_history.history['val_mean_absolute_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %%
mse = mid_model_history.history['mean_squared_error'][3:]
val_mse = mid_model_history.history['val_mean_squared_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mse, 'bo', label='Training MSE')
plt.plot(epochs, val_mse, 'r', label='Validation MSE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.2.2 Testing Medium Complexity FC model
#
# Now its time to prepare my first second submission to the competition, and see if there is any improvement from the Simple Model.
#
# <img src="http://m.quickmeme.com/img/e5/e5e9efb570b2ff99ec37323aded9534797fe25e39a25d3d583a599729c8a9b20.jpg" alt="let this be the last attempt" width="300"/>

# %% [markdown]
# ### 2.2.3 Predict on the test data

# %%
pred = mid_model.predict(test_x)

# %% [markdown]
# ### 2.2.4 Create submission file

# %%
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)

# %%
rowid = list(lookid_data['RowId'])

# %%
feature = []

for f in lookid_list:
    feature.append(lookid_list.index(f))

# %%
preded = []

for x,y in zip(imageID, feature):
    preded.append(pre_list[x][y])

# %%
rowid = pd.Series(rowid, name = 'RowId')
loc = pd.Series(preded, name='Location')

# %%
submission = pd.concat([rowid, loc], axis=1)

# %%
submission.to_csv('submission_mid_model.csv', index=False)

# %% [markdown]
# ### 2.2.5 Results of Medium FC Model
#
# The medium complexity 6 layer fully connected network achieves a Root Mean Squared Error of 3.65 on the competition. This is ranking 99 out of 175 competitors.
#
# This is definitely a better result than the simple model, which ranked 141/175 in the competition. Judging by the plots of training and validation loss, the model does not overfit at all during training, especially with the little regularization.
#
# My next step will be to increase the complexity of the Fully Connected model even more, and regularize when appropriate.

# %% [markdown]
# ## 2.3 Training a Large FC Model
#
# This time around, I'll be adding even more layers to the FC model, and I will add regularization as I see appropriate from observing the behavior of the model during training.
#
# If this does not improve my performance significantly, I will attempt a convolutional neural network.

# %%
def build_large_model():
    """function that defines model with 12 hidden layers, and compiles it. 
    returns compiled model"""
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(9216,))) #1
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu')) #2
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #3
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #5
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #3
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #5
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #3
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #4
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu')) #5
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu')) #8
    model.add(Dense(64, activation='relu')) #12
    model.add(Dense(30))

    rmsprop = optimizers.RMSprop(lr=0.001)
    model.compile(optimizer=rmsprop, loss='mse', metrics=['mae'])
    print(model.summary())
    return model

# %%
large_model = build_large_model()

large_model_history = large_model.fit(train_x, train_y, batch_size=32,
                           epochs=300, validation_split=0.2)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_115 (Dense)            (None, 256)               2359552
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_116 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_117 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_118 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_119 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_120 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_121 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_122 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_123 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_124 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_125 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_126 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_127 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_128 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_129 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_130 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_131 (Dense)            (None, 30)                1950
# =================================================================
# Total params: 3,257,950
# Trainable params: 3,257,950
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 5639 samples, validate on 1410 samples
# Epoch 1/300
# 5639/5639 [==============================] - 3s 603us/step - loss: 1546.5538 - mean_absolute_error: 30.1777 - val_loss: 2267.9505 - val_mean_absolute_error: 44.4056
# Epoch 2/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 988.9148 - mean_absolute_error: 25.2765 - val_loss: 2413.5022 - val_mean_absolute_error: 45.7467
# Epoch 3/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 854.2150 - mean_absolute_error: 23.5806 - val_loss: 2126.8960 - val_mean_absolute_error: 42.9696
# Epoch 4/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 710.3996 - mean_absolute_error: 21.2249 - val_loss: 1916.0071 - val_mean_absolute_error: 40.6565
# Epoch 5/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 662.6489 - mean_absolute_error: 20.3406 - val_loss: 1733.6828 - val_mean_absolute_error: 38.6206
# Epoch 6/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 628.8456 - mean_absolute_error: 19.7716 - val_loss: 1728.3370 - val_mean_absolute_error: 38.6040
# Epoch 7/300
# 5639/5639 [==============================] - 2s 299us/step - loss: 634.1393 - mean_absolute_error: 19.8251 - val_loss: 1951.5373 - val_mean_absolute_error: 41.0919
# Epoch 8/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 601.1251 - mean_absolute_error: 19.3596 - val_loss: 1717.3896 - val_mean_absolute_error: 38.4004
# Epoch 9/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 603.5158 - mean_absolute_error: 19.2361 - val_loss: 1456.0240 - val_mean_absolute_error: 35.3089
# Epoch 10/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 614.8736 - mean_absolute_error: 19.4988 - val_loss: 1664.1122 - val_mean_absolute_error: 38.0750
# Epoch 11/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 605.6664 - mean_absolute_error: 19.3818 - val_loss: 1475.7734 - val_mean_absolute_error: 35.5849
# Epoch 12/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 611.5004 - mean_absolute_error: 19.2303 - val_loss: 1666.6074 - val_mean_absolute_error: 38.0460
# Epoch 13/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 614.0150 - mean_absolute_error: 19.3179 - val_loss: 2064.6668 - val_mean_absolute_error: 42.1757
# Epoch 14/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 635.6008 - mean_absolute_error: 19.5930 - val_loss: 1862.2759 - val_mean_absolute_error: 40.0127
# Epoch 15/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 602.8057 - mean_absolute_error: 19.0910 - val_loss: 2009.8688 - val_mean_absolute_error: 41.6856
# Epoch 16/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 639.3391 - mean_absolute_error: 19.6406 - val_loss: 2274.0674 - val_mean_absolute_error: 44.3161
# Epoch 17/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 636.3979 - mean_absolute_error: 19.7732 - val_loss: 1568.6485 - val_mean_absolute_error: 36.6600
# Epoch 18/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 631.4968 - mean_absolute_error: 19.3147 - val_loss: 2167.2759 - val_mean_absolute_error: 43.4995
# Epoch 19/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 667.0251 - mean_absolute_error: 19.9110 - val_loss: 1677.3458 - val_mean_absolute_error: 38.0544
# Epoch 20/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 655.6274 - mean_absolute_error: 20.0602 - val_loss: 1595.2763 - val_mean_absolute_error: 37.0590
# Epoch 21/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 688.0159 - mean_absolute_error: 20.4143 - val_loss: 2192.6439 - val_mean_absolute_error: 43.5261
# Epoch 22/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 667.9825 - mean_absolute_error: 20.2535 - val_loss: 1587.9154 - val_mean_absolute_error: 36.9360
# Epoch 23/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 643.1192 - mean_absolute_error: 19.8193 - val_loss: 1933.3928 - val_mean_absolute_error: 40.7663
# Epoch 24/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 614.8838 - mean_absolute_error: 19.3964 - val_loss: 1586.0843 - val_mean_absolute_error: 36.8373
# Epoch 25/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 622.6405 - mean_absolute_error: 19.3331 - val_loss: 1600.9081 - val_mean_absolute_error: 37.0246
# Epoch 26/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 762.8046 - mean_absolute_error: 20.5656 - val_loss: 1630.8070 - val_mean_absolute_error: 37.3639
# Epoch 27/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 590.0835 - mean_absolute_error: 18.9770 - val_loss: 1814.9881 - val_mean_absolute_error: 39.4177
# Epoch 28/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 972.5909 - mean_absolute_error: 19.9492 - val_loss: 1641.3648 - val_mean_absolute_error: 37.4898
# Epoch 29/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 607.4821 - mean_absolute_error: 18.8287 - val_loss: 2150.5073 - val_mean_absolute_error: 42.9026
# Epoch 30/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 595.6113 - mean_absolute_error: 19.0812 - val_loss: 2221.5269 - val_mean_absolute_error: 43.6249
# Epoch 31/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 715.8659 - mean_absolute_error: 19.6380 - val_loss: 1708.9789 - val_mean_absolute_error: 38.1681
# Epoch 32/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 642.2751 - mean_absolute_error: 19.5605 - val_loss: 1592.2185 - val_mean_absolute_error: 36.8372
# Epoch 33/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 632.3547 - mean_absolute_error: 19.4970 - val_loss: 1808.1718 - val_mean_absolute_error: 39.2075
# Epoch 34/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 600.0071 - mean_absolute_error: 19.0470 - val_loss: 1899.1590 - val_mean_absolute_error: 40.2818
# Epoch 35/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 676.2175 - mean_absolute_error: 20.0051 - val_loss: 2102.2787 - val_mean_absolute_error: 42.3624
# Epoch 36/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 623.9690 - mean_absolute_error: 19.5070 - val_loss: 1799.4275 - val_mean_absolute_error: 39.1009
# Epoch 37/300
# 5639/5639 [==============================] - 2s 280us/step - loss: 656.3854 - mean_absolute_error: 19.7770 - val_loss: 1763.2512 - val_mean_absolute_error: 38.8644
# Epoch 38/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 619.3408 - mean_absolute_error: 19.2691 - val_loss: 1574.5101 - val_mean_absolute_error: 36.5548
# Epoch 39/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 613.2493 - mean_absolute_error: 19.1119 - val_loss: 1828.6001 - val_mean_absolute_error: 39.3493
# Epoch 40/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 648.6702 - mean_absolute_error: 19.5724 - val_loss: 1712.8466 - val_mean_absolute_error: 38.2165
# Epoch 41/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 636.9531 - mean_absolute_error: 19.1290 - val_loss: 1635.2690 - val_mean_absolute_error: 37.2798
# Epoch 42/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 642.1034 - mean_absolute_error: 19.6347 - val_loss: 1956.1183 - val_mean_absolute_error: 40.8153
# Epoch 43/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 596.9476 - mean_absolute_error: 18.9628 - val_loss: 1596.7016 - val_mean_absolute_error: 36.8277
# Epoch 44/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 619.0694 - mean_absolute_error: 18.7758 - val_loss: 1787.7421 - val_mean_absolute_error: 38.8919
# Epoch 45/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 632.3379 - mean_absolute_error: 19.2868 - val_loss: 1415.0103 - val_mean_absolute_error: 34.4683
# Epoch 46/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 639.4881 - mean_absolute_error: 19.3630 - val_loss: 1980.3147 - val_mean_absolute_error: 40.9742
# Epoch 47/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 637.5997 - mean_absolute_error: 19.4758 - val_loss: 1654.6962 - val_mean_absolute_error: 37.3936
# Epoch 48/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 595.7259 - mean_absolute_error: 18.8977 - val_loss: 1611.3600 - val_mean_absolute_error: 36.9109
# Epoch 49/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 1039.3633 - mean_absolute_error: 19.1164 - val_loss: 1670.5218 - val_mean_absolute_error: 37.6233
# Epoch 50/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 613.3736 - mean_absolute_error: 18.6646 - val_loss: 1833.4443 - val_mean_absolute_error: 39.5101
# Epoch 51/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 794.8901 - mean_absolute_error: 19.4687 - val_loss: 1775.6172 - val_mean_absolute_error: 38.7896
# Epoch 52/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 853.8944 - mean_absolute_error: 18.2346 - val_loss: 1543.8243 - val_mean_absolute_error: 36.0376
# Epoch 53/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 662.6918 - mean_absolute_error: 19.0681 - val_loss: 1659.1601 - val_mean_absolute_error: 37.4232
# Epoch 54/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 620.8847 - mean_absolute_error: 19.1644 - val_loss: 1805.5384 - val_mean_absolute_error: 39.0900
# Epoch 55/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1451.1722 - mean_absolute_error: 19.1729 - val_loss: 1766.4479 - val_mean_absolute_error: 38.6926
# Epoch 56/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 577.6279 - mean_absolute_error: 18.4882 - val_loss: 1668.1606 - val_mean_absolute_error: 37.4767
# Epoch 57/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 996.9951 - mean_absolute_error: 17.9606 - val_loss: 1689.5962 - val_mean_absolute_error: 37.7028
# Epoch 58/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 557.0244 - mean_absolute_error: 17.8946 - val_loss: 1594.4711 - val_mean_absolute_error: 36.7248
# Epoch 59/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 567.9111 - mean_absolute_error: 18.1178 - val_loss: 1507.2611 - val_mean_absolute_error: 35.5677
# Epoch 60/300
# 5639/5639 [==============================] - 2s 276us/step - loss: 644.5837 - mean_absolute_error: 18.8228 - val_loss: 1920.2074 - val_mean_absolute_error: 40.1634
# Epoch 61/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 645.8857 - mean_absolute_error: 19.4377 - val_loss: 1851.5756 - val_mean_absolute_error: 39.4974
# Epoch 62/300
# 5639/5639 [==============================] - 2s 280us/step - loss: 655.9560 - mean_absolute_error: 17.8879 - val_loss: 1484.4874 - val_mean_absolute_error: 35.1115
# Epoch 63/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 592.4321 - mean_absolute_error: 18.7067 - val_loss: 1539.1313 - val_mean_absolute_error: 35.9534
# Epoch 64/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 635.0198 - mean_absolute_error: 19.1180 - val_loss: 1475.7587 - val_mean_absolute_error: 35.0676
# Epoch 65/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 549.8596 - mean_absolute_error: 17.8818 - val_loss: 1725.9870 - val_mean_absolute_error: 38.0407
# Epoch 66/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 566.9070 - mean_absolute_error: 18.0799 - val_loss: 1362.1398 - val_mean_absolute_error: 33.6905
# Epoch 67/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 570.1845 - mean_absolute_error: 17.8433 - val_loss: 1575.3019 - val_mean_absolute_error: 36.2897
# Epoch 68/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 517.1869 - mean_absolute_error: 17.4736 - val_loss: 1544.3491 - val_mean_absolute_error: 35.8876
# Epoch 69/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 661.8641 - mean_absolute_error: 18.7675 - val_loss: 1592.3654 - val_mean_absolute_error: 36.4619
# Epoch 70/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 584.6462 - mean_absolute_error: 18.3116 - val_loss: 1479.5163 - val_mean_absolute_error: 35.0683
# Epoch 71/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 544.9664 - mean_absolute_error: 17.9613 - val_loss: 1427.3782 - val_mean_absolute_error: 34.5361
# Epoch 72/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 519.4981 - mean_absolute_error: 17.1540 - val_loss: 1678.9773 - val_mean_absolute_error: 37.5509
# Epoch 73/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 784.8659 - mean_absolute_error: 18.0002 - val_loss: 1628.5736 - val_mean_absolute_error: 36.8248
# Epoch 74/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 543.4181 - mean_absolute_error: 17.7532 - val_loss: 1339.7453 - val_mean_absolute_error: 33.1377
# Epoch 75/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 678.9188 - mean_absolute_error: 18.5361 - val_loss: 1782.5844 - val_mean_absolute_error: 38.5337
# Epoch 76/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 757.4080 - mean_absolute_error: 17.5383 - val_loss: 1604.4284 - val_mean_absolute_error: 36.3873
# Epoch 77/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 574.3374 - mean_absolute_error: 17.5390 - val_loss: 1545.9289 - val_mean_absolute_error: 35.8225
# Epoch 78/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 16663.2309 - mean_absolute_error: 18.5316 - val_loss: 1452.2155 - val_mean_absolute_error: 34.8258
# Epoch 79/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 533.7521 - mean_absolute_error: 17.4306 - val_loss: 1564.5224 - val_mean_absolute_error: 36.0401
# Epoch 80/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 554.0416 - mean_absolute_error: 17.5446 - val_loss: 1346.8181 - val_mean_absolute_error: 33.3356
# Epoch 81/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 555.3152 - mean_absolute_error: 17.8365 - val_loss: 1516.2526 - val_mean_absolute_error: 35.3954
# Epoch 82/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 637.7361 - mean_absolute_error: 17.4500 - val_loss: 1350.9336 - val_mean_absolute_error: 33.3365
# Epoch 83/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 520.7215 - mean_absolute_error: 17.4648 - val_loss: 1418.3882 - val_mean_absolute_error: 34.2596
# Epoch 84/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 591.3433 - mean_absolute_error: 18.4551 - val_loss: 1434.9255 - val_mean_absolute_error: 34.3612
# Epoch 85/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 566.4910 - mean_absolute_error: 18.2173 - val_loss: 1388.9812 - val_mean_absolute_error: 33.8416
# Epoch 86/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 615.5249 - mean_absolute_error: 18.6217 - val_loss: 1383.5905 - val_mean_absolute_error: 33.6958
# Epoch 87/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 599.7264 - mean_absolute_error: 18.9491 - val_loss: 1725.6435 - val_mean_absolute_error: 37.7865
# Epoch 88/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 1252.7203 - mean_absolute_error: 22.2746 - val_loss: 1803.0550 - val_mean_absolute_error: 38.2798
# Epoch 89/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1152.7122 - mean_absolute_error: 24.1819 - val_loss: 1618.8042 - val_mean_absolute_error: 36.4951
# Epoch 90/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 2399.9931 - mean_absolute_error: 33.7098 - val_loss: 1893.5488 - val_mean_absolute_error: 39.4386
# Epoch 91/300
# 5639/5639 [==============================] - 2s 276us/step - loss: 1885.9548 - mean_absolute_error: 39.3445 - val_loss: 1879.6210 - val_mean_absolute_error: 39.2617
# Epoch 92/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 1885.5115 - mean_absolute_error: 39.2052 - val_loss: 1865.7628 - val_mean_absolute_error: 39.0849
# Epoch 93/300
# 5639/5639 [==============================] - 2s 278us/step - loss: 1881.1861 - mean_absolute_error: 39.0436 - val_loss: 1851.9857 - val_mean_absolute_error: 38.9084
# Epoch 94/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 1905.8079 - mean_absolute_error: 38.7455 - val_loss: 1838.6542 - val_mean_absolute_error: 38.7374
# Epoch 95/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 2275.7796 - mean_absolute_error: 35.0363 - val_loss: 1658.4537 - val_mean_absolute_error: 36.5872
# Epoch 96/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 689.2755 - mean_absolute_error: 19.7843 - val_loss: 1537.0314 - val_mean_absolute_error: 35.3851
# Epoch 97/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 957.9347 - mean_absolute_error: 18.2979 - val_loss: 1657.5463 - val_mean_absolute_error: 36.7684
# Epoch 98/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 697.8040 - mean_absolute_error: 18.7848 - val_loss: 1602.1467 - val_mean_absolute_error: 36.1280
# Epoch 99/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 566.0247 - mean_absolute_error: 17.8093 - val_loss: 1544.4680 - val_mean_absolute_error: 35.4085
# Epoch 100/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 857.3762 - mean_absolute_error: 17.2341 - val_loss: 1162.8015 - val_mean_absolute_error: 30.5509
# Epoch 101/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 748.7787 - mean_absolute_error: 18.4622 - val_loss: 1732.9598 - val_mean_absolute_error: 37.5647
# Epoch 102/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 1035.6129 - mean_absolute_error: 21.0555 - val_loss: 1613.4539 - val_mean_absolute_error: 36.2247
# Epoch 103/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 565.1713 - mean_absolute_error: 17.8925 - val_loss: 1305.2559 - val_mean_absolute_error: 32.4100
# Epoch 104/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 549.2390 - mean_absolute_error: 17.6725 - val_loss: 1517.9516 - val_mean_absolute_error: 35.2153
# Epoch 105/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 552.0496 - mean_absolute_error: 17.2373 - val_loss: 1279.4460 - val_mean_absolute_error: 32.0662
# Epoch 106/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 568.3403 - mean_absolute_error: 17.5079 - val_loss: 1155.5441 - val_mean_absolute_error: 30.3546
# Epoch 107/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 721.8449 - mean_absolute_error: 17.9352 - val_loss: 1588.3867 - val_mean_absolute_error: 35.8442
# Epoch 108/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 617.8219 - mean_absolute_error: 18.1634 - val_loss: 1339.5331 - val_mean_absolute_error: 32.8527
# Epoch 109/300
# 5639/5639 [==============================] - 2s 305us/step - loss: 561.7438 - mean_absolute_error: 17.0918 - val_loss: 1356.4907 - val_mean_absolute_error: 33.0555
# Epoch 110/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 520.4466 - mean_absolute_error: 17.2088 - val_loss: 1525.0653 - val_mean_absolute_error: 35.1174
# Epoch 111/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 657.5191 - mean_absolute_error: 18.7874 - val_loss: 1531.7714 - val_mean_absolute_error: 35.1804
# Epoch 112/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 1399.8509 - mean_absolute_error: 22.0769 - val_loss: 1648.3101 - val_mean_absolute_error: 36.4064
# Epoch 113/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 2030.7274 - mean_absolute_error: 35.7035 - val_loss: 1684.4674 - val_mean_absolute_error: 36.7219
# Epoch 114/300
# 5639/5639 [==============================] - 2s 278us/step - loss: 1709.4252 - mean_absolute_error: 36.6822 - val_loss: 1671.5140 - val_mean_absolute_error: 36.5454
# Epoch 115/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 1664.6961 - mean_absolute_error: 36.4528 - val_loss: 1658.6085 - val_mean_absolute_error: 36.3686
# Epoch 116/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 1651.6146 - mean_absolute_error: 36.2740 - val_loss: 1645.7713 - val_mean_absolute_error: 36.1920
# Epoch 117/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 1644.1771 - mean_absolute_error: 36.1171 - val_loss: 1632.9982 - val_mean_absolute_error: 36.0154
# Epoch 118/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 1626.1275 - mean_absolute_error: 35.9216 - val_loss: 1620.2869 - val_mean_absolute_error: 35.8388
# Epoch 119/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 1621.0982 - mean_absolute_error: 35.7688 - val_loss: 1607.6397 - val_mean_absolute_error: 35.6623
# Epoch 120/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 1600.8333 - mean_absolute_error: 35.5682 - val_loss: 1595.0541 - val_mean_absolute_error: 35.4857
# Epoch 121/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 1588.2767 - mean_absolute_error: 35.3916 - val_loss: 1582.5279 - val_mean_absolute_error: 35.3092
# Epoch 122/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 1575.7847 - mean_absolute_error: 35.2149 - val_loss: 1570.0660 - val_mean_absolute_error: 35.1327
# Epoch 123/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1563.3576 - mean_absolute_error: 35.0383 - val_loss: 1557.6689 - val_mean_absolute_error: 34.9562
# Epoch 124/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 1550.9916 - mean_absolute_error: 34.8618 - val_loss: 1545.3324 - val_mean_absolute_error: 34.7798
# Epoch 125/300
# 5639/5639 [==============================] - 2s 279us/step - loss: 1538.6856 - mean_absolute_error: 34.6852 - val_loss: 1533.0576 - val_mean_absolute_error: 34.6034
# Epoch 126/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 1526.4432 - mean_absolute_error: 34.5087 - val_loss: 1520.8462 - val_mean_absolute_error: 34.4271
# Epoch 127/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 1514.2677 - mean_absolute_error: 34.3322 - val_loss: 1508.6991 - val_mean_absolute_error: 34.2508
# Epoch 128/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1502.1519 - mean_absolute_error: 34.1559 - val_loss: 1496.6131 - val_mean_absolute_error: 34.0745
# Epoch 129/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 1490.0964 - mean_absolute_error: 33.9795 - val_loss: 1484.5895 - val_mean_absolute_error: 33.8983
# Epoch 130/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 1478.1082 - mean_absolute_error: 33.8032 - val_loss: 1472.6305 - val_mean_absolute_error: 33.7221
# Epoch 131/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 1466.1793 - mean_absolute_error: 33.6270 - val_loss: 1460.7321 - val_mean_absolute_error: 33.5460
# Epoch 132/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 1454.3159 - mean_absolute_error: 33.4508 - val_loss: 1448.8974 - val_mean_absolute_error: 33.3700
# Epoch 133/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 1442.5128 - mean_absolute_error: 33.2747 - val_loss: 1437.1245 - val_mean_absolute_error: 33.1940
# Epoch 134/300
# 5639/5639 [==============================] - 2s 302us/step - loss: 1430.7713 - mean_absolute_error: 33.0987 - val_loss: 1425.4148 - val_mean_absolute_error: 33.0181
# Epoch 135/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 1419.0937 - mean_absolute_error: 32.9227 - val_loss: 1413.7663 - val_mean_absolute_error: 32.8423
# Epoch 136/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 1407.4783 - mean_absolute_error: 32.7468 - val_loss: 1402.1821 - val_mean_absolute_error: 32.6665
# Epoch 137/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1395.9275 - mean_absolute_error: 32.5710 - val_loss: 1390.6599 - val_mean_absolute_error: 32.4909
# Epoch 138/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 1384.4385 - mean_absolute_error: 32.3953 - val_loss: 1379.2003 - val_mean_absolute_error: 32.3152
# Epoch 139/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 1372.8159 - mean_absolute_error: 32.2165 - val_loss: 1367.8045 - val_mean_absolute_error: 32.1398
# Epoch 140/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 1361.4359 - mean_absolute_error: 32.0402 - val_loss: 1356.4704 - val_mean_absolute_error: 31.9643
# Epoch 141/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 1350.3439 - mean_absolute_error: 31.8687 - val_loss: 1345.1977 - val_mean_absolute_error: 31.7889
# Epoch 142/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 1339.1054 - mean_absolute_error: 31.6933 - val_loss: 1333.9891 - val_mean_absolute_error: 31.6136
# Epoch 143/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 1327.9272 - mean_absolute_error: 31.5181 - val_loss: 1322.8427 - val_mean_absolute_error: 31.4385
# Epoch 144/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 2923.0127 - mean_absolute_error: 24.9202 - val_loss: 1241.1634 - val_mean_absolute_error: 30.5317
# Epoch 145/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 538.5687 - mean_absolute_error: 16.7663 - val_loss: 1156.4303 - val_mean_absolute_error: 29.4103
# Epoch 146/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 384.9565 - mean_absolute_error: 14.6798 - val_loss: 823.1645 - val_mean_absolute_error: 24.6110
# Epoch 147/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 456.1632 - mean_absolute_error: 13.8824 - val_loss: 1191.6921 - val_mean_absolute_error: 29.8425
# Epoch 148/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 764.8772 - mean_absolute_error: 17.3260 - val_loss: 952.0860 - val_mean_absolute_error: 26.4890
# Epoch 149/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 405.5787 - mean_absolute_error: 14.7141 - val_loss: 818.4080 - val_mean_absolute_error: 24.5172
# Epoch 150/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 471.4687 - mean_absolute_error: 15.9721 - val_loss: 1098.1393 - val_mean_absolute_error: 28.5526
# Epoch 151/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 477.3503 - mean_absolute_error: 14.3960 - val_loss: 991.7810 - val_mean_absolute_error: 27.0364
# Epoch 152/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 523.8815 - mean_absolute_error: 15.9589 - val_loss: 1083.8696 - val_mean_absolute_error: 28.2941
# Epoch 153/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 1065.0835 - mean_absolute_error: 16.5045 - val_loss: 1155.2398 - val_mean_absolute_error: 29.2645
# Epoch 154/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 438.7912 - mean_absolute_error: 15.5138 - val_loss: 1063.1536 - val_mean_absolute_error: 27.9719
# Epoch 155/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 669.5024 - mean_absolute_error: 16.3572 - val_loss: 897.3667 - val_mean_absolute_error: 25.6172
# Epoch 156/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 2315.4681 - mean_absolute_error: 15.5589 - val_loss: 988.1171 - val_mean_absolute_error: 26.8608
# Epoch 157/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 1162.9595 - mean_absolute_error: 20.5910 - val_loss: 1232.1986 - val_mean_absolute_error: 30.0331
# Epoch 158/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 659.9022 - mean_absolute_error: 18.6172 - val_loss: 1108.5541 - val_mean_absolute_error: 28.4898
# Epoch 159/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 789.2111 - mean_absolute_error: 19.8618 - val_loss: 1219.0021 - val_mean_absolute_error: 29.8429
# Epoch 160/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 9772.7158 - mean_absolute_error: 30.6772 - val_loss: 1207.1259 - val_mean_absolute_error: 29.6272
# Epoch 161/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 3417.7831 - mean_absolute_error: 29.8926 - val_loss: 1197.6750 - val_mean_absolute_error: 29.4754
# Epoch 162/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 2221.3996 - mean_absolute_error: 30.4787 - val_loss: 1176.3970 - val_mean_absolute_error: 29.1133
# Epoch 163/300
# 5639/5639 [==============================] - 2s 280us/step - loss: 1139.8995 - mean_absolute_error: 24.3659 - val_loss: 1178.7223 - val_mean_absolute_error: 29.1732
# Epoch 164/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 2109.6885 - mean_absolute_error: 29.6705 - val_loss: 1170.2471 - val_mean_absolute_error: 29.0284
# Epoch 165/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 1164.8660 - mean_absolute_error: 28.9406 - val_loss: 1160.0689 - val_mean_absolute_error: 28.8564
# Epoch 166/300
# 5639/5639 [==============================] - 2s 298us/step - loss: 3842.7285 - mean_absolute_error: 29.6716 - val_loss: 1150.9620 - val_mean_absolute_error: 28.7070
# Epoch 167/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 12574.8506 - mean_absolute_error: 32.6244 - val_loss: 1085.3374 - val_mean_absolute_error: 27.6867
# Epoch 168/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 1350.6108 - mean_absolute_error: 23.0351 - val_loss: 1091.2767 - val_mean_absolute_error: 27.8924
# Epoch 169/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 1128.9755 - mean_absolute_error: 25.5466 - val_loss: 1124.6836 - val_mean_absolute_error: 28.2732
# Epoch 170/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 28475.5115 - mean_absolute_error: 30.4854 - val_loss: 1116.2558 - val_mean_absolute_error: 28.1287
# Epoch 171/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 771.2173 - mean_absolute_error: 21.3975 - val_loss: 1090.2146 - val_mean_absolute_error: 27.7736
# Epoch 172/300
# 5639/5639 [==============================] - 2s 279us/step - loss: 2472.3782 - mean_absolute_error: 27.0220 - val_loss: 1085.7348 - val_mean_absolute_error: 27.6554
# Epoch 173/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 1053.1059 - mean_absolute_error: 21.9672 - val_loss: 1078.4424 - val_mean_absolute_error: 27.5485
# Epoch 174/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 2607.9756 - mean_absolute_error: 23.8167 - val_loss: 1083.1043 - val_mean_absolute_error: 27.5574
# Epoch 175/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 771.0032 - mean_absolute_error: 20.0039 - val_loss: 1064.6669 - val_mean_absolute_error: 27.3008
# Epoch 176/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 1252.1130 - mean_absolute_error: 23.8317 - val_loss: 1024.7555 - val_mean_absolute_error: 26.7751
# Epoch 177/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 849.5642 - mean_absolute_error: 21.2315 - val_loss: 1061.6172 - val_mean_absolute_error: 27.1788
# Epoch 178/300
# 5639/5639 [==============================] - 2s 300us/step - loss: 1473.1100 - mean_absolute_error: 22.4545 - val_loss: 997.4230 - val_mean_absolute_error: 26.3192
# Epoch 179/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 3565.9869 - mean_absolute_error: 22.0785 - val_loss: 1039.7652 - val_mean_absolute_error: 26.8399
# Epoch 180/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 1045.1577 - mean_absolute_error: 21.2385 - val_loss: 930.6425 - val_mean_absolute_error: 25.3845
# Epoch 181/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 820.2958 - mean_absolute_error: 19.7977 - val_loss: 946.1954 - val_mean_absolute_error: 25.5284
# Epoch 182/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 816.9672 - mean_absolute_error: 21.1890 - val_loss: 1020.3357 - val_mean_absolute_error: 26.4642
# Epoch 183/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 595.3569 - mean_absolute_error: 17.7163 - val_loss: 898.5024 - val_mean_absolute_error: 24.8107
# Epoch 184/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 1772.4914 - mean_absolute_error: 14.8094 - val_loss: 917.7954 - val_mean_absolute_error: 25.0478
# Epoch 185/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 457.5111 - mean_absolute_error: 15.0685 - val_loss: 788.6194 - val_mean_absolute_error: 23.1204
# Epoch 186/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 696.8684 - mean_absolute_error: 19.7725 - val_loss: 982.5799 - val_mean_absolute_error: 25.9751
# Epoch 187/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 755.5756 - mean_absolute_error: 19.0595 - val_loss: 985.1638 - val_mean_absolute_error: 25.8791
# Epoch 188/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 1059.9158 - mean_absolute_error: 24.8821 - val_loss: 977.6815 - val_mean_absolute_error: 25.6911
# Epoch 189/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 715.2586 - mean_absolute_error: 20.2566 - val_loss: 935.4084 - val_mean_absolute_error: 25.0631
# Epoch 190/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 682.6211 - mean_absolute_error: 18.7439 - val_loss: 928.5108 - val_mean_absolute_error: 25.0708
# Epoch 191/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 589.9487 - mean_absolute_error: 18.2277 - val_loss: 909.6102 - val_mean_absolute_error: 24.6544
# Epoch 192/300
# 5639/5639 [==============================] - 2s 299us/step - loss: 728.8074 - mean_absolute_error: 17.3625 - val_loss: 945.3820 - val_mean_absolute_error: 25.1737
# Epoch 193/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 948.0795 - mean_absolute_error: 21.1782 - val_loss: 870.1206 - val_mean_absolute_error: 24.0886
# Epoch 194/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 546.8410 - mean_absolute_error: 17.1814 - val_loss: 817.4233 - val_mean_absolute_error: 23.3535
# Epoch 195/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 760.7615 - mean_absolute_error: 21.0538 - val_loss: 759.3690 - val_mean_absolute_error: 22.3947
# Epoch 196/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 663.4137 - mean_absolute_error: 19.0591 - val_loss: 913.4015 - val_mean_absolute_error: 24.5400
# Epoch 197/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 621.2547 - mean_absolute_error: 18.0412 - val_loss: 732.3579 - val_mean_absolute_error: 21.8489
# Epoch 198/300
# 5639/5639 [==============================] - 2s 298us/step - loss: 1207.1924 - mean_absolute_error: 21.9088 - val_loss: 909.4709 - val_mean_absolute_error: 24.4326
# Epoch 199/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 4184.1505 - mean_absolute_error: 24.1068 - val_loss: 890.3761 - val_mean_absolute_error: 24.1646
# Epoch 200/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 572.1528 - mean_absolute_error: 17.6372 - val_loss: 887.6368 - val_mean_absolute_error: 24.1410
# Epoch 201/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 698.8199 - mean_absolute_error: 18.5516 - val_loss: 833.3457 - val_mean_absolute_error: 23.3255
# Epoch 202/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 655.2050 - mean_absolute_error: 18.3723 - val_loss: 879.2072 - val_mean_absolute_error: 23.9754
# Epoch 203/300
# 5639/5639 [==============================] - 2s 300us/step - loss: 65529.7988 - mean_absolute_error: 28.2720 - val_loss: 876.6041 - val_mean_absolute_error: 23.8028
# Epoch 204/300
# 5639/5639 [==============================] - 2s 307us/step - loss: 872.0566 - mean_absolute_error: 23.7080 - val_loss: 868.2385 - val_mean_absolute_error: 23.6343
# Epoch 205/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 863.6486 - mean_absolute_error: 23.5382 - val_loss: 859.9356 - val_mean_absolute_error: 23.4667
# Epoch 206/300
# 5639/5639 [==============================] - 2s 303us/step - loss: 1457216.6071 - mean_absolute_error: 52.4113 - val_loss: 855.0899 - val_mean_absolute_error: 23.3720
# Epoch 207/300
# 5639/5639 [==============================] - 2s 298us/step - loss: 906.3500 - mean_absolute_error: 20.2781 - val_loss: 848.4228 - val_mean_absolute_error: 23.2614
# Epoch 208/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 2112.0843 - mean_absolute_error: 18.5872 - val_loss: 807.4119 - val_mean_absolute_error: 22.6179
# Epoch 209/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 726.8180 - mean_absolute_error: 18.5469 - val_loss: 692.1608 - val_mean_absolute_error: 20.8163
# Epoch 210/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 1011.5149 - mean_absolute_error: 16.8601 - val_loss: 783.9276 - val_mean_absolute_error: 22.4074
# Epoch 211/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 551.3316 - mean_absolute_error: 16.8134 - val_loss: 792.4299 - val_mean_absolute_error: 22.4260
# Epoch 212/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 663.1685 - mean_absolute_error: 17.8823 - val_loss: 715.6293 - val_mean_absolute_error: 21.1898
# Epoch 213/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 550.9979 - mean_absolute_error: 16.4975 - val_loss: 809.8210 - val_mean_absolute_error: 22.5264
# Epoch 214/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 665.9273 - mean_absolute_error: 19.1733 - val_loss: 779.7328 - val_mean_absolute_error: 22.0911
# Epoch 215/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 608.5885 - mean_absolute_error: 17.9017 - val_loss: 797.7260 - val_mean_absolute_error: 22.2970
# Epoch 216/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 876.2116 - mean_absolute_error: 21.7670 - val_loss: 790.8734 - val_mean_absolute_error: 22.1084
# Epoch 217/300
# 5639/5639 [==============================] - 2s 300us/step - loss: 948.4438 - mean_absolute_error: 22.0822 - val_loss: 783.0837 - val_mean_absolute_error: 21.9571
# Epoch 218/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 928.2363 - mean_absolute_error: 21.3318 - val_loss: 776.7254 - val_mean_absolute_error: 21.8389
# Epoch 219/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1368.2835 - mean_absolute_error: 22.2788 - val_loss: 769.4745 - val_mean_absolute_error: 21.6682
# Epoch 220/300
# 5639/5639 [==============================] - 2s 285us/step - loss: 687.1521 - mean_absolute_error: 18.4305 - val_loss: 735.0988 - val_mean_absolute_error: 21.1704
# Epoch 221/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 514.5758 - mean_absolute_error: 15.8671 - val_loss: 562.3983 - val_mean_absolute_error: 18.3371
# Epoch 222/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 704.9790 - mean_absolute_error: 19.5283 - val_loss: 710.9039 - val_mean_absolute_error: 20.3738
# Epoch 223/300
# 5639/5639 [==============================] - 2s 306us/step - loss: 823.4470 - mean_absolute_error: 20.9175 - val_loss: 743.3596 - val_mean_absolute_error: 21.1204
# Epoch 224/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 817.9731 - mean_absolute_error: 20.7039 - val_loss: 736.6021 - val_mean_absolute_error: 20.9769
# Epoch 225/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 1164.2183 - mean_absolute_error: 21.3214 - val_loss: 729.7080 - val_mean_absolute_error: 20.8271
# Epoch 226/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 736.3293 - mean_absolute_error: 19.1367 - val_loss: 723.2766 - val_mean_absolute_error: 20.6886
# Epoch 227/300
# 5639/5639 [==============================] - 2s 298us/step - loss: 666.0266 - mean_absolute_error: 18.2064 - val_loss: 444.3776 - val_mean_absolute_error: 15.9972
# Epoch 228/300
# 5639/5639 [==============================] - 2s 299us/step - loss: 629.4401 - mean_absolute_error: 17.4765 - val_loss: 675.2330 - val_mean_absolute_error: 20.0994
# Epoch 229/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 890.9987 - mean_absolute_error: 18.2288 - val_loss: 623.4933 - val_mean_absolute_error: 19.1396
# Epoch 230/300
# 5639/5639 [==============================] - 2s 296us/step - loss: 638.4425 - mean_absolute_error: 18.3138 - val_loss: 699.0253 - val_mean_absolute_error: 20.1717
# Epoch 231/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 785.5110 - mean_absolute_error: 19.8077 - val_loss: 682.2959 - val_mean_absolute_error: 19.9487
# Epoch 232/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 533.6321 - mean_absolute_error: 15.5643 - val_loss: 577.6541 - val_mean_absolute_error: 18.2830
# Epoch 233/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 451.4146 - mean_absolute_error: 14.8312 - val_loss: 677.1436 - val_mean_absolute_error: 19.7699
# Epoch 234/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 503.5278 - mean_absolute_error: 15.6359 - val_loss: 671.8102 - val_mean_absolute_error: 19.6762
# Epoch 235/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 604.0508 - mean_absolute_error: 15.2765 - val_loss: 514.5330 - val_mean_absolute_error: 17.0001
# Epoch 236/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 557.2901 - mean_absolute_error: 16.0410 - val_loss: 664.1296 - val_mean_absolute_error: 19.4322
# Epoch 237/300
# 5639/5639 [==============================] - 2s 294us/step - loss: 541.6842 - mean_absolute_error: 16.0967 - val_loss: 649.3540 - val_mean_absolute_error: 19.1665
# Epoch 238/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 591.5107 - mean_absolute_error: 16.2555 - val_loss: 481.6943 - val_mean_absolute_error: 16.4592
# Epoch 239/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 516.2005 - mean_absolute_error: 14.4223 - val_loss: 634.1130 - val_mean_absolute_error: 18.9198
# Epoch 240/300
# 5639/5639 [==============================] - 2s 286us/step - loss: 540.8627 - mean_absolute_error: 16.1163 - val_loss: 640.5042 - val_mean_absolute_error: 18.9041
# Epoch 241/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 672.0276 - mean_absolute_error: 18.5087 - val_loss: 614.6956 - val_mean_absolute_error: 18.4240
# Epoch 242/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 446.2980 - mean_absolute_error: 13.1190 - val_loss: 531.9739 - val_mean_absolute_error: 17.1822
# Epoch 243/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 406.7300 - mean_absolute_error: 13.2615 - val_loss: 573.3350 - val_mean_absolute_error: 17.7723
# Epoch 244/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 664.1563 - mean_absolute_error: 16.5659 - val_loss: 615.3264 - val_mean_absolute_error: 18.4263
# Epoch 245/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 476.0502 - mean_absolute_error: 13.8807 - val_loss: 565.8933 - val_mean_absolute_error: 17.5529
# Epoch 246/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 655.8190 - mean_absolute_error: 16.4167 - val_loss: 610.9844 - val_mean_absolute_error: 18.2474
# Epoch 247/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 1606.9376 - mean_absolute_error: 16.7947 - val_loss: 523.8354 - val_mean_absolute_error: 16.8537
# Epoch 248/300
# 5639/5639 [==============================] - 2s 293us/step - loss: 332.8927 - mean_absolute_error: 12.0524 - val_loss: 482.7105 - val_mean_absolute_error: 16.1060
# Epoch 249/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 948.4622 - mean_absolute_error: 17.4935 - val_loss: 581.2936 - val_mean_absolute_error: 17.6672
# Epoch 250/300
# 5639/5639 [==============================] - 2s 301us/step - loss: 547.5718 - mean_absolute_error: 13.8948 - val_loss: 436.1071 - val_mean_absolute_error: 14.3947
# Epoch 251/300
# 5639/5639 [==============================] - 2s 306us/step - loss: 290.6982 - mean_absolute_error: 11.3402 - val_loss: 552.4357 - val_mean_absolute_error: 17.2560
# Epoch 252/300
# 5639/5639 [==============================] - 2s 302us/step - loss: 416.3604 - mean_absolute_error: 12.6629 - val_loss: 379.3961 - val_mean_absolute_error: 13.6560
# Epoch 253/300
# 5639/5639 [==============================] - 2s 299us/step - loss: 492.4283 - mean_absolute_error: 14.7048 - val_loss: 1029.0465 - val_mean_absolute_error: 14.4283
# Epoch 254/300
# 5639/5639 [==============================] - 2s 303us/step - loss: 409.2626 - mean_absolute_error: 13.0405 - val_loss: 2207.7941 - val_mean_absolute_error: 16.3364
# Epoch 255/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 190.4735 - mean_absolute_error: 8.2177 - val_loss: 848.8708 - val_mean_absolute_error: 14.6400
# Epoch 256/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 172.2786 - mean_absolute_error: 8.4476 - val_loss: 3306.3691 - val_mean_absolute_error: 15.2147
# Epoch 257/300
# 5639/5639 [==============================] - 2s 278us/step - loss: 238.1247 - mean_absolute_error: 10.0817 - val_loss: 509.5227 - val_mean_absolute_error: 16.1652
# Epoch 258/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 568.7445 - mean_absolute_error: 13.1323 - val_loss: 532.7861 - val_mean_absolute_error: 16.7173
# Epoch 259/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 360.8688 - mean_absolute_error: 12.1703 - val_loss: 548.2100 - val_mean_absolute_error: 16.9738
# Epoch 260/300
# 5639/5639 [==============================] - 2s 297us/step - loss: 427.0127 - mean_absolute_error: 14.3734 - val_loss: 520.3570 - val_mean_absolute_error: 16.2141
# Epoch 261/300
# 5639/5639 [==============================] - 2s 287us/step - loss: 1957.0124 - mean_absolute_error: 16.8574 - val_loss: 543.4669 - val_mean_absolute_error: 16.7507
# Epoch 262/300
# 5639/5639 [==============================] - 2s 299us/step - loss: 483.5049 - mean_absolute_error: 15.2256 - val_loss: 534.5568 - val_mean_absolute_error: 16.5363
# Epoch 263/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 557.0692 - mean_absolute_error: 16.5440 - val_loss: 1146.3343 - val_mean_absolute_error: 14.5105
# Epoch 264/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 382.4251 - mean_absolute_error: 12.7359 - val_loss: 10715.1258 - val_mean_absolute_error: 15.2637
# Epoch 265/300
# 5639/5639 [==============================] - 2s 302us/step - loss: 254.3782 - mean_absolute_error: 9.6983 - val_loss: 12880.5227 - val_mean_absolute_error: 14.0346
# Epoch 266/300
# 5639/5639 [==============================] - 2s 295us/step - loss: 123.5550 - mean_absolute_error: 7.3137 - val_loss: 24839.5966 - val_mean_absolute_error: 13.1132
# Epoch 267/300
# 5639/5639 [==============================] - 2s 290us/step - loss: 125.0772 - mean_absolute_error: 6.2750 - val_loss: 41092.3920 - val_mean_absolute_error: 13.3291
# Epoch 268/300
# 5639/5639 [==============================] - 2s 287us/step - loss:
# Epoch 290/300
# 5639/5639 [==============================] - 2s 292us/step - loss: 51.0325 - mean_absolute_error: 4.5912 - val_loss: 25252.6894 - val_mean_absolute_error: 14.9373
# Epoch 291/300
# 5639/5639 [==============================] - 2s 283us/step - loss: 51.2279 - mean_absolute_error: 4.5284 - val_loss: 38855.9934 - val_mean_absolute_error: 14.8970
# Epoch 292/300
# 5639/5639 [==============================] - 2s 289us/step - loss: 48.5374 - mean_absolute_error: 4.4412 - val_loss: 67431.3425 - val_mean_absolute_error: 14.8069
# Epoch 293/300
# 5639/5639 [==============================] - 2s 281us/step - loss: 47.7379 - mean_absolute_error: 4.4148 - val_loss: 42411.0955 - val_mean_absolute_error: 14.8441
# Epoch 294/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 53.9614 - mean_absolute_error: 4.3133 - val_loss: 72207.5441 - val_mean_absolute_error: 15.0849
# Epoch 295/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 43.4187 - mean_absolute_error: 4.1948 - val_loss: 72013.6428 - val_mean_absolute_error: 15.2348
# Epoch 296/300
# 5639/5639 [==============================] - 2s 284us/step - loss: 44.6819 - mean_absolute_error: 4.2461 - val_loss: 51464.6807 - val_mean_absolute_error: 15.2428
# Epoch 297/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 56.2540 - mean_absolute_error: 4.2477 - val_loss: 69172.7421 - val_mean_absolute_error: 15.2234
# Epoch 298/300
# 5639/5639 [==============================] - 2s 291us/step - loss: 47.4396 - mean_absolute_error: 3.9969 - val_loss: 30371.8604 - val_mean_absolute_error: 15.1739
# Epoch 299/300
# 5639/5639 [==============================] - 2s 288us/step - loss: 42.7775 - mean_absolute_error: 4.1350 - val_loss: 87114.8929 - val_mean_absolute_error: 15.3337
# Epoch 300/300
# 5639/5639 [==============================] - 2s 282us/step - loss: 55.0931 - mean_absolute_error: 4.0972 - val_loss: 44641.2550 - val_mean_absolute_error: 15.3394

# %%
loss = large_model_history.history['loss'][3:]
val_loss = large_model_history.history['val_loss'][3:]

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = large_model_history.history['mean_absolute_error'][3:]
val_mae = large_model_history.history['val_mean_absolute_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.3.1 Results of Medium FC Model
#
# I attemped several different "deeper" FC models. Some with a large 512 node layer at the beginning, and some with at most 128 node layers. I tried gradually decreasing the size of the layers, or keeping them the same, etc.
#
# During training the validation loss was oscillating, and not decresing. Model was overfitting even with lots of regularization. I concluded that an FC model is not the best solution to this problem.
# Given that this is a vision problem, I will attempt a Convolutional Neural Network to solve it.

# %%
submission.to_csv('submission_mid_model.csv', index=False)

# %% [markdown]
# ## 2.4 Training a Convolutional Neural Network
#
# After the big failure of the "deeper" fully connected layer for this problem, I felt like I should do some reading.
# I found a [research paper ](https://arxiv.org/pdf/1710.00977.pdf) in arxiv.org that helped me get an idea of a possible good starting point for a CNN.
#
# Let's see how the CNN does!

# %%
train_x_cnn = train_x.reshape(7049,96,96,1)

# %%
def build_cnn_model():
    """function that defines convolutional neural network model, and compiles it. 
    returns compiled model"""
    model = Sequential()

    model.add(Conv2D(32, (4,4), input_shape=(96,96,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(128, (2,2)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(128, (1,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(30))

    adamopt = optimizers.Adam()
    
    model.compile(optimizer=adamopt, loss='mse', metrics=['mae'])
    print(model.summary())
    return model

# %%
cnn_model = build_cnn_model()

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                               cooldown=0, patience=6, min_lr=0.5e-6, verbose=1)

cnn_model_history = cnn_model.fit(train_x_cnn, train_y, batch_size=64,
                           epochs=50, validation_split=0.2,
                           callbacks=[lr_reducer])
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_57 (Conv2D)           (None, 93, 93, 32)        544
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 93, 93, 32)        128
# _________________________________________________________________
# activation_56 (Activation)   (None, 93, 93, 32)        0
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 44, 44, 64)        18496
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 44, 44, 64)        256
# _________________________________________________________________
# activation_57 (Activation)   (None, 44, 44, 64)        0
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 21, 21, 128)       32896
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 21, 21, 128)       512
# _________________________________________________________________
# activation_58 (Activation)   (None, 21, 21, 128)       0
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 10, 10, 128)       16512
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# activation_59 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 3200)              0
# _________________________________________________________________
# dense_174 (Dense)            (None, 256)               819456
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_175 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_176 (Dense)            (None, 30)                3870
# =================================================================
# Total params: 926,078
# Trainable params: 925,374
# Non-trainable params: 704
# _________________________________________________________________
# None
# Train on 5639 samples, validate on 1410 samples
# Epoch 1/50
# 5639/5639 [==============================] - 6s 1ms/step - loss: 220.3092 - mean_absolute_error: 8.4842 - val_loss: 84.0813 - val_mean_absolute_error: 8.0764
# Epoch 2/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 23.2770 - mean_absolute_error: 3.6507 - val_loss: 44.2686 - val_mean_absolute_error: 5.7299
# Epoch 3/50
# 5639/5639 [==============================] - 2s 329us/step - loss: 19.5715 - mean_absolute_error: 3.3227 - val_loss: 21.5919 - val_mean_absolute_error: 3.6431
# Epoch 4/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 18.0368 - mean_absolute_error: 3.1732 - val_loss: 21.5965 - val_mean_absolute_error: 3.7531
# Epoch 5/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 16.7568 - mean_absolute_error: 3.0463 - val_loss: 18.0275 - val_mean_absolute_error: 3.2477
# Epoch 6/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 15.5572 - mean_absolute_error: 2.9108 - val_loss: 9.0863 - val_mean_absolute_error: 1.9962
# Epoch 7/50
# 5639/5639 [==============================] - 2s 332us/step - loss: 15.5797 - mean_absolute_error: 2.9158 - val_loss: 28.0727 - val_mean_absolute_error: 4.4763
# Epoch 8/50
# 5639/5639 [==============================] - 2s 333us/step - loss: 14.9631 - mean_absolute_error: 2.8554 - val_loss: 9.6359 - val_mean_absolute_error: 2.0727
# Epoch 9/50
# 5639/5639 [==============================] - 2s 335us/step - loss: 14.2567 - mean_absolute_error: 2.7820 - val_loss: 7.7490 - val_mean_absolute_error: 1.6947
# Epoch 10/50
# 5639/5639 [==============================] - 2s 338us/step - loss: 14.2478 - mean_absolute_error: 2.7709 - val_loss: 10.3348 - val_mean_absolute_error: 2.1930
# Epoch 11/50
# 5639/5639 [==============================] - 2s 338us/step - loss: 14.2348 - mean_absolute_error: 2.7783 - val_loss: 14.4705 - val_mean_absolute_error: 2.9404
# Epoch 12/50
# 5639/5639 [==============================] - 2s 338us/step - loss: 13.1659 - mean_absolute_error: 2.6513 - val_loss: 7.5354 - val_mean_absolute_error: 1.6972
# Epoch 13/50
# 5639/5639 [==============================] - 2s 341us/step - loss: 13.3989 - mean_absolute_error: 2.6896 - val_loss: 25.6916 - val_mean_absolute_error: 4.2162
# Epoch 14/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 13.8288 - mean_absolute_error: 2.7199 - val_loss: 26.4836 - val_mean_absolute_error: 4.3435
# Epoch 15/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 13.7108 - mean_absolute_error: 2.7130 - val_loss: 25.6018 - val_mean_absolute_error: 4.2266
# Epoch 16/50
# 5639/5639 [==============================] - 2s 334us/step - loss: 13.6405 - mean_absolute_error: 2.7088 - val_loss: 13.2001 - val_mean_absolute_error: 2.6850
# Epoch 17/50
# 5639/5639 [==============================] - 2s 332us/step - loss: 12.5599 - mean_absolute_error: 2.5834 - val_loss: 8.5067 - val_mean_absolute_error: 1.9567
# Epoch 18/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 11.7147 - mean_absolute_error: 2.4887 - val_loss: 24.2436 - val_mean_absolute_error: 4.1038
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 19/50
# 5639/5639 [==============================] - 2s 331us/step - loss: 10.7968 - mean_absolute_error: 2.3831 - val_loss: 8.1665 - val_mean_absolute_error: 1.9065
# Epoch 20/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 10.5711 - mean_absolute_error: 2.3507 - val_loss: 6.8330 - val_mean_absolute_error: 1.5977
# Epoch 21/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 10.6091 - mean_absolute_error: 2.3525 - val_loss: 6.2919 - val_mean_absolute_error: 1.4597
# Epoch 22/50
# 5639/5639 [==============================] - 2s 326us/step - loss: 10.7084 - mean_absolute_error: 2.3688 - val_loss: 6.2671 - val_mean_absolute_error: 1.4605
# Epoch 23/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 10.4072 - mean_absolute_error: 2.3268 - val_loss: 7.1677 - val_mean_absolute_error: 1.6920
# Epoch 24/50
# 5639/5639 [==============================] - 2s 329us/step - loss: 10.4745 - mean_absolute_error: 2.3311 - val_loss: 7.6824 - val_mean_absolute_error: 1.8245
# Epoch 25/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 10.2139 - mean_absolute_error: 2.3071 - val_loss: 7.9383 - val_mean_absolute_error: 1.8832
# Epoch 26/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 10.3862 - mean_absolute_error: 2.3314 - val_loss: 7.2632 - val_mean_absolute_error: 1.7345
# Epoch 27/50
# 5639/5639 [==============================] - 2s 330us/step - loss: 10.2308 - mean_absolute_error: 2.3116 - val_loss: 7.5406 - val_mean_absolute_error: 1.7856
# Epoch 28/50
# 5639/5639 [==============================] - 2s 326us/step - loss: 10.2639 - mean_absolute_error: 2.3211 - val_loss: 7.4047 - val_mean_absolute_error: 1.7613
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 29/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 10.0730 - mean_absolute_error: 2.2806 - val_loss: 6.5680 - val_mean_absolute_error: 1.5561
# Epoch 30/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.9614 - mean_absolute_error: 2.2746 - val_loss: 6.8929 - val_mean_absolute_error: 1.6405
# Epoch 31/50
# 5639/5639 [==============================] - 2s 329us/step - loss: 10.1980 - mean_absolute_error: 2.2954 - val_loss: 6.7647 - val_mean_absolute_error: 1.6097
# Epoch 32/50
# 5639/5639 [==============================] - 2s 333us/step - loss: 9.9889 - mean_absolute_error: 2.2697 - val_loss: 6.8437 - val_mean_absolute_error: 1.6260
# Epoch 33/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 10.0040 - mean_absolute_error: 2.2775 - val_loss: 7.3077 - val_mean_absolute_error: 1.7455
# Epoch 34/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 10.0168 - mean_absolute_error: 2.2720 - val_loss: 6.8872 - val_mean_absolute_error: 1.6399
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 35/50
# 5639/5639 [==============================] - 2s 326us/step - loss: 9.9848 - mean_absolute_error: 2.2834 - val_loss: 6.8855 - val_mean_absolute_error: 1.6397
# Epoch 36/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.9715 - mean_absolute_error: 2.2746 - val_loss: 6.8180 - val_mean_absolute_error: 1.6219
# Epoch 37/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.8718 - mean_absolute_error: 2.2605 - val_loss: 6.8777 - val_mean_absolute_error: 1.6374
# Epoch 38/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 10.0201 - mean_absolute_error: 2.2812 - val_loss: 6.7530 - val_mean_absolute_error: 1.6050
# Epoch 39/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 9.9923 - mean_absolute_error: 2.2755 - val_loss: 6.7987 - val_mean_absolute_error: 1.6165
# Epoch 40/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 10.0707 - mean_absolute_error: 2.2856 - val_loss: 6.7883 - val_mean_absolute_error: 1.6138
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 5e-07.
# Epoch 41/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 10.0258 - mean_absolute_error: 2.2836 - val_loss: 6.8315 - val_mean_absolute_error: 1.6256
# Epoch 42/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 9.8747 - mean_absolute_error: 2.2640 - val_loss: 6.8336 - val_mean_absolute_error: 1.6260
# Epoch 43/50
# 5639/5639 [==============================] - 2s 325us/step - loss: 9.9067 - mean_absolute_error: 2.2683 - val_loss: 6.8314 - val_mean_absolute_error: 1.6259
# Epoch 44/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 9.9861 - mean_absolute_error: 2.2730 - val_loss: 6.7931 - val_mean_absolute_error: 1.6158
# Epoch 45/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 10.0761 - mean_absolute_error: 2.2874 - val_loss: 6.7993 - val_mean_absolute_error: 1.6177
# Epoch 46/50
# 5639/5639 [==============================] - 2s 326us/step - loss: 9.9560 - mean_absolute_error: 2.2699 - val_loss: 6.8919 - val_mean_absolute_error: 1.6417
# Epoch 47/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.9867 - mean_absolute_error: 2.2737 - val_loss: 6.8433 - val_mean_absolute_error: 1.6293
# Epoch 48/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.9564 - mean_absolute_error: 2.2718 - val_loss: 6.8339 - val_mean_absolute_error: 1.6266
# Epoch 49/50
# 5639/5639 [==============================] - 2s 328us/step - loss: 9.9230 - mean_absolute_error: 2.2624 - val_loss: 6.8231 - val_mean_absolute_error: 1.6235
# Epoch 50/50
# 5639/5639 [==============================] - 2s 327us/step - loss: 10.0015 - mean_absolute_error: 2.2679 - val_loss: 6.8192 - val_mean_absolute_error: 1.6228

# %%
loss = cnn_model_history.history['loss'][3:]
val_loss = cnn_model_history.history['val_loss'][3:]

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = cnn_model_history.history['mean_absolute_error'][3:]
val_mae = cnn_model_history.history['val_mean_absolute_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.2.2 Testing ConvNet model
#
# Now its time to prepare my third submission to the competition, and see if there is any improvement from the Fully Connected model.
#
# <img src="http://m.quickmeme.com/img/c9/c9e377d277dd66bf7540a9e0302d68227f585312751d7e9e0b1dac0a509709fd.jpg" width="300"/>

# %% [markdown]
# ### 2.2.3 Predict on the test data

# %%
test_x_cnn = test_x.reshape(1783, 96, 96, 1)

# %%
pred = cnn_model.predict(test_x_cnn)

# %% [markdown]
# ### 2.2.4 Create submission file

# %%
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)

# %%
rowid = list(lookid_data['RowId'])

# %%
feature = []

for f in lookid_list:
    feature.append(lookid_list.index(f))

# %%
preded = []

for x,y in zip(imageID, feature):
    preded.append(pre_list[x][y])

# %%
rowid = pd.Series(rowid, name = 'RowId')
loc = pd.Series(preded, name='Location')

# %%
submission = pd.concat([rowid, loc], axis=1)

# %%
submission.to_csv('submission_cnn_model.csv', index=False)

# %% [markdown]
# ### 2.2.5 Results of First CNN Model
#
# This convolutional neural network achieves a RMSE of 3.35 on the competition, which is ranking 80/175. This is a nice improvement from the 6 layer FC which had achieved ranking 99/175.
#
# Even though this CNN is definitely better than the FC model, I expected a much better result. For some reason the validation loss (RMSE_Val) is much lower (better) than the training loss, but my competition score agrees more with the training loss.
#
# I also had to change the optimizer, because RMSprop was oscilating too much.
#
#
# My next step will be to continue to explore CNN designs, and optimizers.

# %% [markdown]
# ## 2.5 Training an improved CNN
#
# The previous CNN did better than the FC networks. Now its time to try adding some model complexity so we can drive the training loss down.

# %%
train_x_cnn = train_x.reshape(7049,96,96,1)

# %%
def build_cnn2_model():
    """function that defines convolutional neural network model, and compiles it. 
    returns compiled model"""
    model = Sequential()

    model.add(Conv2D(32, (4,4), input_shape=(96,96,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(128, (2,2)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(256, (1,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))

    model.add(Dense(128, activation='relu'))

    model.add(Dense(30))

    adamopt = optimizers.Adam()
    
    model.compile(optimizer=adamopt, loss='mse', metrics=['mae'])
    print(model.summary())
    return model

# %%
cnn2_model = build_cnn2_model()

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                               cooldown=0, patience=9, min_lr=0.5e-6, verbose=1)

cnn2_model_history = cnn2_model.fit(train_x_cnn, train_y, batch_size=64,
                           epochs=70, validation_split=0.2,
                           callbacks=[lr_reducer])
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_143 (Conv2D)          (None, 93, 93, 32)        544
# _________________________________________________________________
# batch_normalization_142 (Bat (None, 93, 93, 32)        128
# _________________________________________________________________
# activation_142 (Activation)  (None, 93, 93, 32)        0
# _________________________________________________________________
# max_pooling2d_122 (MaxPoolin (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 44, 44, 64)        18496
# _________________________________________________________________
# batch_normalization_143 (Bat (None, 44, 44, 64)        256
# _________________________________________________________________
# activation_143 (Activation)  (None, 44, 44, 64)        0
# _________________________________________________________________
# max_pooling2d_123 (MaxPoolin (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 20, 20, 64)        36928
# _________________________________________________________________
# batch_normalization_144 (Bat (None, 20, 20, 64)        256
# _________________________________________________________________
# activation_144 (Activation)  (None, 20, 20, 64)        0
# _________________________________________________________________
# max_pooling2d_124 (MaxPoolin (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 9, 9, 128)         32896
# _________________________________________________________________
# batch_normalization_145 (Bat (None, 9, 9, 128)         512
# _________________________________________________________________
# activation_145 (Activation)  (None, 9, 9, 128)         0
# _________________________________________________________________
# max_pooling2d_125 (MaxPoolin (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 4, 4, 256)         33024
# _________________________________________________________________
# batch_normalization_146 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_146 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_126 (MaxPoolin (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dropout_119 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_230 (Dense)            (None, 256)               262400
# _________________________________________________________________
# dense_231 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_232 (Dense)            (None, 30)                3870
# =================================================================
# Total params: 423,230
# Trainable params: 422,142
# Non-trainable params: 1,088
# _________________________________________________________________
# None
# Train on 5639 samples, validate on 1410 samples
# Epoch 1/70
# 5639/5639 [==============================] - 12s 2ms/step - loss: 248.7690 - mean_absolute_error: 8.5503 - val_loss: 139.2230 - val_mean_absolute_error: 10.6602
# Epoch 2/70
# 5639/5639 [==============================] - 2s 356us/step - loss: 15.9272 - mean_absolute_error: 2.8968 - val_loss: 28.5854 - val_mean_absolute_error: 4.3472
# Epoch 3/70
# 5639/5639 [==============================] - 2s 359us/step - loss: 15.5966 - mean_absolute_error: 2.8644 - val_loss: 35.2871 - val_mean_absolute_error: 4.9213
# Epoch 4/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 15.4717 - mean_absolute_error: 2.8537 - val_loss: 16.4708 - val_mean_absolute_error: 2.9584
# Epoch 5/70
# 5639/5639 [==============================] - 2s 355us/step - loss: 13.9982 - mean_absolute_error: 2.6965 - val_loss: 10.6511 - val_mean_absolute_error: 2.1678
# Epoch 6/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 13.4069 - mean_absolute_error: 2.6419 - val_loss: 29.8611 - val_mean_absolute_error: 4.5130
# Epoch 7/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 14.5643 - mean_absolute_error: 2.7817 - val_loss: 9.2736 - val_mean_absolute_error: 1.9767
# Epoch 8/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 12.6709 - mean_absolute_error: 2.5757 - val_loss: 8.3719 - val_mean_absolute_error: 1.8055
# Epoch 9/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 12.1996 - mean_absolute_error: 2.5117 - val_loss: 21.4788 - val_mean_absolute_error: 3.7673
# Epoch 10/70
# 5639/5639 [==============================] - 2s 355us/step - loss: 12.4437 - mean_absolute_error: 2.5564 - val_loss: 10.4324 - val_mean_absolute_error: 2.2503
# Epoch 11/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 12.8820 - mean_absolute_error: 2.6110 - val_loss: 17.5653 - val_mean_absolute_error: 3.2554
# Epoch 12/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 11.4051 - mean_absolute_error: 2.4250 - val_loss: 8.0633 - val_mean_absolute_error: 1.7869
# Epoch 13/70
# 5639/5639 [==============================] - 2s 356us/step - loss: 11.5460 - mean_absolute_error: 2.4373 - val_loss: 15.6577 - val_mean_absolute_error: 3.0431
# Epoch 14/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 11.1638 - mean_absolute_error: 2.4052 - val_loss: 9.3897 - val_mean_absolute_error: 2.0137
# Epoch 15/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 11.3514 - mean_absolute_error: 2.4368 - val_loss: 22.0504 - val_mean_absolute_error: 3.8530
# Epoch 16/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 10.9044 - mean_absolute_error: 2.3844 - val_loss: 9.6439 - val_mean_absolute_error: 2.0523
# Epoch 17/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 11.1958 - mean_absolute_error: 2.4183 - val_loss: 7.5425 - val_mean_absolute_error: 1.7695
# Epoch 18/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 10.0112 - mean_absolute_error: 2.2695 - val_loss: 11.4536 - val_mean_absolute_error: 2.5008
# Epoch 19/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 10.5455 - mean_absolute_error: 2.3471 - val_loss: 13.4120 - val_mean_absolute_error: 2.8097
# Epoch 20/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 10.4087 - mean_absolute_error: 2.3300 - val_loss: 7.8548 - val_mean_absolute_error: 1.8491
# Epoch 21/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 10.3908 - mean_absolute_error: 2.3184 - val_loss: 10.8674 - val_mean_absolute_error: 2.3533
# Epoch 22/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 9.9124 - mean_absolute_error: 2.2651 - val_loss: 9.9915 - val_mean_absolute_error: 2.0804
# Epoch 23/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 10.0944 - mean_absolute_error: 2.2867 - val_loss: 7.5533 - val_mean_absolute_error: 1.8354
# Epoch 24/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 10.5882 - mean_absolute_error: 2.3720 - val_loss: 6.9769 - val_mean_absolute_error: 1.6510
# Epoch 25/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 10.1386 - mean_absolute_error: 2.3037 - val_loss: 6.2768 - val_mean_absolute_error: 1.5101
# Epoch 26/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 9.4005 - mean_absolute_error: 2.1997 - val_loss: 17.0042 - val_mean_absolute_error: 3.2471
# Epoch 27/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 9.9947 - mean_absolute_error: 2.2860 - val_loss: 10.7768 - val_mean_absolute_error: 2.4569
# Epoch 28/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 9.8468 - mean_absolute_error: 2.2742 - val_loss: 9.3440 - val_mean_absolute_error: 2.1267
# Epoch 29/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 9.5220 - mean_absolute_error: 2.2280 - val_loss: 8.5957 - val_mean_absolute_error: 1.9009
# Epoch 30/70
# 5639/5639 [==============================] - 2s 356us/step - loss: 9.2516 - mean_absolute_error: 2.1958 - val_loss: 6.8485 - val_mean_absolute_error: 1.6406
# Epoch 31/70
# 5639/5639 [==============================] - 2s 356us/step - loss: 9.1045 - mean_absolute_error: 2.1841 - val_loss: 6.4832 - val_mean_absolute_error: 1.5684
# Epoch 32/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 9.0948 - mean_absolute_error: 2.1778 - val_loss: 13.2533 - val_mean_absolute_error: 2.9037
# Epoch 33/70
# 5639/5639 [==============================] - 2s 357us/step - loss: 8.7798 - mean_absolute_error: 2.1415 - val_loss: 9.6146 - val_mean_absolute_error: 2.1958
# Epoch 34/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 8.6882 - mean_absolute_error: 2.1155 - val_loss: 11.4416 - val_mean_absolute_error: 2.4417
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 35/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 8.0729 - mean_absolute_error: 2.0377 - val_loss: 5.3812 - val_mean_absolute_error: 1.3430
# Epoch 36/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.9392 - mean_absolute_error: 2.0157 - val_loss: 5.4825 - val_mean_absolute_error: 1.3731
# Epoch 37/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.8327 - mean_absolute_error: 2.0035 - val_loss: 5.6534 - val_mean_absolute_error: 1.4147
# Epoch 38/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.7365 - mean_absolute_error: 1.9913 - val_loss: 5.8466 - val_mean_absolute_error: 1.4950
# Epoch 39/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 7.8759 - mean_absolute_error: 2.0168 - val_loss: 5.7175 - val_mean_absolute_error: 1.4248
# Epoch 40/70
# 5639/5639 [==============================] - 2s 346us/step - loss: 7.6094 - mean_absolute_error: 1.9730 - val_loss: 5.3447 - val_mean_absolute_error: 1.3343
# Epoch 41/70
# 5639/5639 [==============================] - 2s 347us/step - loss: 7.6164 - mean_absolute_error: 1.9677 - val_loss: 5.5296 - val_mean_absolute_error: 1.3915
# Epoch 42/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 7.6636 - mean_absolute_error: 1.9826 - val_loss: 5.2590 - val_mean_absolute_error: 1.3190
# Epoch 43/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 7.6121 - mean_absolute_error: 1.9730 - val_loss: 5.3094 - val_mean_absolute_error: 1.3311
# Epoch 44/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 7.6088 - mean_absolute_error: 1.9650 - val_loss: 5.4537 - val_mean_absolute_error: 1.3735
# Epoch 45/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 7.5881 - mean_absolute_error: 1.9680 - val_loss: 5.2738 - val_mean_absolute_error: 1.3220
# Epoch 46/70
# 5639/5639 [==============================] - 2s 348us/step - loss: 7.5885 - mean_absolute_error: 1.9710 - val_loss: 5.4810 - val_mean_absolute_error: 1.3809
# Epoch 47/70
# 5639/5639 [==============================] - 2s 356us/step - loss: 7.4918 - mean_absolute_error: 1.9514 - val_loss: 5.4349 - val_mean_absolute_error: 1.3756
# Epoch 48/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.4464 - mean_absolute_error: 1.9531 - val_loss: 5.2061 - val_mean_absolute_error: 1.3122
# Epoch 49/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 7.4115 - mean_absolute_error: 1.9503 - val_loss: 5.1878 - val_mean_absolute_error: 1.3171
# Epoch 50/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 7.3906 - mean_absolute_error: 1.9397 - val_loss: 6.3806 - val_mean_absolute_error: 1.6205
# Epoch 51/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 7.4565 - mean_absolute_error: 1.9561 - val_loss: 5.4357 - val_mean_absolute_error: 1.3697
# Epoch 52/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.4738 - mean_absolute_error: 1.9576 - val_loss: 5.7110 - val_mean_absolute_error: 1.4718
# Epoch 53/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.6953 - mean_absolute_error: 1.9900 - val_loss: 5.1596 - val_mean_absolute_error: 1.3029
# Epoch 54/70
# 5639/5639 [==============================] - 2s 348us/step - loss: 7.3820 - mean_absolute_error: 1.9424 - val_loss: 5.1899 - val_mean_absolute_error: 1.3250
# Epoch 55/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.3790 - mean_absolute_error: 1.9442 - val_loss: 5.2436 - val_mean_absolute_error: 1.3260
# Epoch 56/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.4299 - mean_absolute_error: 1.9502 - val_loss: 5.1995 - val_mean_absolute_error: 1.3135
# Epoch 57/70
# 5639/5639 [==============================] - 2s 352us/step - loss: 7.2955 - mean_absolute_error: 1.9286 - val_loss: 5.2196 - val_mean_absolute_error: 1.3415
# Epoch 58/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 7.4080 - mean_absolute_error: 1.9521 - val_loss: 5.3381 - val_mean_absolute_error: 1.3657
# Epoch 59/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.2846 - mean_absolute_error: 1.9299 - val_loss: 5.4847 - val_mean_absolute_error: 1.4028
# Epoch 60/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 7.3617 - mean_absolute_error: 1.9437 - val_loss: 5.2256 - val_mean_absolute_error: 1.3241
# Epoch 61/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.3428 - mean_absolute_error: 1.9394 - val_loss: 5.1263 - val_mean_absolute_error: 1.3004
# Epoch 62/70
# 5639/5639 [==============================] - 2s 351us/step - loss: 7.2110 - mean_absolute_error: 1.9193 - val_loss: 5.1413 - val_mean_absolute_error: 1.3120
# Epoch 63/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.2769 - mean_absolute_error: 1.9367 - val_loss: 5.0770 - val_mean_absolute_error: 1.2865
# Epoch 64/70
# 5639/5639 [==============================] - 2s 350us/step - loss: 7.2618 - mean_absolute_error: 1.9275 - val_loss: 5.2394 - val_mean_absolute_error: 1.3336
# Epoch 65/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 7.2063 - mean_absolute_error: 1.9172 - val_loss: 5.4703 - val_mean_absolute_error: 1.3849
# Epoch 66/70
# 5639/5639 [==============================] - 2s 349us/step - loss: 7.1457 - mean_absolute_error: 1.9056 - val_loss: 5.2770 - val_mean_absolute_error: 1.3376
# Epoch 67/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 7.2126 - mean_absolute_error: 1.9253 - val_loss: 5.2817 - val_mean_absolute_error: 1.3515
# Epoch 68/70
# 5639/5639 [==============================] - 2s 353us/step - loss: 7.2650 - mean_absolute_error: 1.9332 - val_loss: 5.6427 - val_mean_absolute_error: 1.4524
# Epoch 69/70
# 5639/5639 [==============================] - 2s 354us/step - loss: 7.1733 - mean_absolute_error: 1.9205 - val_loss: 5.2723 - val_mean_absolute_error: 1.3663
# Epoch 70/70
# 5639/5639 [==============================] - 2s 348us/step - loss: 7.1965 - mean_absolute_error: 1.9277 - val_loss: 5.0689 - val_mean_absolute_error: 1.2944

# %%
loss = cnn2_model_history.history['loss'][3:]
val_loss = cnn2_model_history.history['val_loss'][3:]

epochs = range(len(loss))

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = cnn2_model_history.history['mean_absolute_error'][3:]
val_mae = cnn2_model_history.history['val_mean_absolute_error'][3:]

epochs = range(len(mae))

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.2.2 Testing ConvNet model
#
# Now its time to prepare my third submission to the competition, and see if there is any improvement from the Fully Connected model.
#
# <img src="http://m.quickmeme.com/img/c9/c9e377d277dd66bf7540a9e0302d68227f585312751d7e9e0b1dac0a509709fd.jpg" width="300"/>

# %% [markdown]
# ### 2.2.3 Predict on the test data

# %%
test_x_cnn = test_x.reshape(1783, 96, 96, 1)

# %%
pred = cnn2_model.predict(test_x_cnn)

# %% [markdown]
# ### 2.2.4 Create submission file

# %%
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)

# %%
rowid = list(lookid_data['RowId'])

# %%
feature = []

for f in lookid_list:
    feature.append(lookid_list.index(f))

# %%
preded = []

for x,y in zip(imageID, feature):
    preded.append(pre_list[x][y])

# %%
rowid = pd.Series(rowid, name = 'RowId')
loc = pd.Series(preded, name='Location')

# %%
submission = pd.concat([rowid, loc], axis=1)

# %%
submission.to_csv('submission_cnn3_model.csv', index=False)

# %% [markdown]
# ### 2.2.5 Results of Second CNN Model
#
# This convolutional neural network achieves a RMSE of 2.89 on the competition, which is ranking 56/175. This is a really nice improvement from the previous CNN which had achieved ranking 80/175.
#
# What changed between the previous CNN and this one?
# One additional Conv2D layer of 64 (3,3) filters, and the replacement of the last Conv2D layer to have 256 (1,1) filters instead of 128 (1,1) filters.
